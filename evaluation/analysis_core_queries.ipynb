# %%
from evaluate import load_runs_metadata_table, evaluate_arp, evaluate_replicability, evaluate_result_delta, long_table, table_ARP_statsig, evaluate_reproducibility
from plot import result_table, table_ARP_full, table_RD_DRI, plot_DRI_ER, plot_arp, plot_per_topic_dif, plot_per_topic, plot_per_topic_delta

# %%
df = load_runs_metadata_table(mode = "-core_queries")
df = evaluate_arp(df, mode = "-core_queries")
df = evaluate_result_delta(df)
# Out:
# /home/jueri/dev/DCIR/evaluation/evaluate.py:105: RuntimeWarning: invalid value encountered in double_scalars
#   return (base - advanced) / base
# /home/jueri/dev/DCIR/evaluation/evaluate.py:105: RuntimeWarning: divide by zero encountered in double_scalars
#   return (base - advanced) / base
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),
# /home/jueri/dev/DCIR/evaluation/evaluate.py:142: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   table["result_delta"].apply(pd.Series),

# %%
df = evaluate_replicability(df, mode = "-core_queries")
# Out:
# /home/jueri/miniconda3/envs/LongEval/lib/python3.8/site-packages/repro_eval/measure/overall_effects.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   yield measure, value / mi_orig.get(measure)
# /home/jueri/miniconda3/envs/LongEval/lib/python3.8/site-packages/repro_eval/measure/overall_effects.py:82: RuntimeWarning: divide by zero encountered in double_scalars
#   yield measure, value / mi_orig.get(measure)
# /home/jueri/miniconda3/envs/LongEval/lib/python3.8/site-packages/repro_eval/measure/overall_effects.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   yield measure, (mean - mean_scores_b.get(measure)) / mean_scores_b.get(measure)

# %%
df = evaluate_reproducibility(df, mode = "-core_queries")
# Out:
# Error KTau run-tripclick-test-head-t2-queries-bm25+monot5-pyterrier
# Error KTau run-tripclick-test-head-t3-queries-rrf(xsqram__bm25_bo1__pl2)-ranx
# Error KTau run-tripclick-test-head-t2-queries-rrf(xsqram__bm25_bo1__pl2)-ranx
# Error KTau run-tripclick-test-head-t3-queries-bm25+colbert-pyterrier
# Error KTau run-tripclick-test-head-t2-queries-bm25_d2q10-pyterrier
# Error KTau run-tripclick-test-head-t3-queries-bm25+monot5-pyterrier
# Error KTau run-tripclick-test-head-t2-queries-bm25+colbert-pyterrier
# Error KTau run-tripclick-test-head-t3-queries-bm25_d2q10-pyterrier

# %%
long = long_table(df)

# %% [markdown]
# # Table

# %%
table_ARP_statsig(df, dataset="longeval", subcollections=["WT", "ST", "LT"], highlight=True, mode="-core_queries")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:1418, in HTTPSConnection.connect(self)
#    1416 "Connect to a host on a given (SSL) port."
# -> 1418 super().connect()
#    1420 if self._tunnel_host:
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/http/client.py:922, in HTTPConnection.connect(self)
#     921 """Connect to the host and port specified in __init__."""
# --> 922 self.sock = self._create_connection(
#     923     (self.host,self.port), self.timeout, self.source_address)
#     924 self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/socket.py:787, in create_connection(address, timeout, source_address)
#     786 err = None
# --> 787 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788     af, socktype, proto, canonname, sa = res
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 table_ARP_statsig(df, dataset="longeval", subcollections=["WT", "ST", "LT"], highlight=True, mode="-core_queries")
#
# File ~/dev/DCIR/evaluation/evaluate.py:387, in table_ARP_statsig(df, dataset, subcollections, highlight, save, mode)
#     384 import pyterrier as pt
#     386 if not pt.started():
# --> 387     pt.init()
#     389 def mark_stat_sig(row):
#     390     for measure in MEASURES:
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/pyterrier/__init__.py:109, in init(version, mem, packages, jvm_opts, redirect_io, logging, home_dir, boot_packages, tqdm, no_download, helper_version)
#     106     os.mkdir(HOME_DIR)
#     108 # get the initial classpath for the JVM
# --> 109 classpathTrJars, hlpr_ver = setup_terrier(HOME_DIR, version, helper_version = helper_version, boot_packages=boot_packages, force_download=not no_download)
#     110 global _helper_version
#     111 _helper_version = hlpr_ver
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/pyterrier/bootstrap.py:163, in setup_terrier(file_path, terrier_version, helper_version, boot_packages, force_download)
#     161 # If version is not specified, find newest and download it
#     162 if terrier_version is None:
# --> 163     terrier_version = mavenresolver.latest_version_num(TERRIER_PKG, "terrier-assemblies")
#     164 else:
#     165     terrier_version = str(terrier_version) # just in case its a float
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/pyterrier/mavenresolver.py:66, in latest_version_num(orgName, packageName)
#      63     return("-SNAPSHOT")
#      65 url_str = MAVEN_BASE_URL + orgName + "/" + packageName + "/maven-metadata.xml"
# ---> 66 with urllib.request.urlopen(url_str) as url:
#      67     xml_str = url.read()
#      68 xmldoc = minidom.parseString(xml_str)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/urllib/request.py:1357, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1354         h.request(req.get_method(), req.selector, req.data, headers,
#    1355                   encode_chunked=req.has_header('Transfer-encoding'))
#    1356     except OSError as err: # timeout error
# -> 1357         raise URLError(err)
#    1358     r = h.getresponse()
#    1359 except:
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>

# %%
table_ARP_statsig(df, dataset="tripclick-test-head", subcollections=["t1", "t2", "t3"], highlight=True, mode="-core_queries")
# Out:
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# <style type="text/css">
# #T_34b53_row4_col0, #T_34b53_row4_col1, #T_34b53_row4_col2, #T_34b53_row6_col0, #T_34b53_row6_col1, #T_34b53_row6_col2, #T_34b53_row11_col0, #T_34b53_row11_col1, #T_34b53_row11_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_34b53">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >subcollection</th>
#       <th id="T_34b53_level0_col0" class="col_heading level0 col0" >t1</th>
#       <th id="T_34b53_level0_col1" class="col_heading level0 col1" >t2</th>
#       <th id="T_34b53_level0_col2" class="col_heading level0 col2" >t3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >measure</th>
#       <th class="index_name level1" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34b53_level0_row0" class="row_heading level0 row0" rowspan="5">ndcg</th>
#       <th id="T_34b53_level1_row0" class="row_heading level1 row0" >BM25</th>
#       <td id="T_34b53_row0_col0" class="data row0 col0" >0.280</td>
#       <td id="T_34b53_row0_col1" class="data row0 col1" >0.323</td>
#       <td id="T_34b53_row0_col2" class="data row0 col2" >0.334</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row1" class="row_heading level1 row1" >ColBERT</th>
#       <td id="T_34b53_row1_col0" class="data row1 col0" >0.298*</td>
#       <td id="T_34b53_row1_col1" class="data row1 col1" >0.337*</td>
#       <td id="T_34b53_row1_col2" class="data row1 col2" >0.35*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row2" class="row_heading level1 row2" >MonoT5</th>
#       <td id="T_34b53_row2_col0" class="data row2 col0" >0.291</td>
#       <td id="T_34b53_row2_col1" class="data row2 col1" >0.334*</td>
#       <td id="T_34b53_row2_col2" class="data row2 col2" >0.347*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row3" class="row_heading level1 row3" >RRF</th>
#       <td id="T_34b53_row3_col0" class="data row3 col0" >0.285</td>
#       <td id="T_34b53_row3_col1" class="data row3 col1" >0.326</td>
#       <td id="T_34b53_row3_col2" class="data row3 col2" >0.338*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row4" class="row_heading level1 row4" >d2q</th>
#       <td id="T_34b53_row4_col0" class="data row4 col0" >0.303*</td>
#       <td id="T_34b53_row4_col1" class="data row4 col1" >0.349*</td>
#       <td id="T_34b53_row4_col2" class="data row4 col2" >0.363*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level0_row5" class="row_heading level0 row5" rowspan="5">bpref</th>
#       <th id="T_34b53_level1_row5" class="row_heading level1 row5" >BM25</th>
#       <td id="T_34b53_row5_col0" class="data row5 col0" >0.405</td>
#       <td id="T_34b53_row5_col1" class="data row5 col1" >0.350</td>
#       <td id="T_34b53_row5_col2" class="data row5 col2" >0.301</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row6" class="row_heading level1 row6" >ColBERT</th>
#       <td id="T_34b53_row6_col0" class="data row6 col0" >0.451*</td>
#       <td id="T_34b53_row6_col1" class="data row6 col1" >0.391*</td>
#       <td id="T_34b53_row6_col2" class="data row6 col2" >0.342*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row7" class="row_heading level1 row7" >MonoT5</th>
#       <td id="T_34b53_row7_col0" class="data row7 col0" >0.435*</td>
#       <td id="T_34b53_row7_col1" class="data row7 col1" >0.372*</td>
#       <td id="T_34b53_row7_col2" class="data row7 col2" >0.328*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row8" class="row_heading level1 row8" >RRF</th>
#       <td id="T_34b53_row8_col0" class="data row8 col0" >0.406</td>
#       <td id="T_34b53_row8_col1" class="data row8 col1" >0.358</td>
#       <td id="T_34b53_row8_col2" class="data row8 col2" >0.307*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row9" class="row_heading level1 row9" >d2q</th>
#       <td id="T_34b53_row9_col0" class="data row9 col0" >0.435*</td>
#       <td id="T_34b53_row9_col1" class="data row9 col1" >0.378*</td>
#       <td id="T_34b53_row9_col2" class="data row9 col2" >0.326*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level0_row10" class="row_heading level0 row10" rowspan="5">P\_10</th>
#       <th id="T_34b53_level1_row10" class="row_heading level1 row10" >BM25</th>
#       <td id="T_34b53_row10_col0" class="data row10 col0" >0.081</td>
#       <td id="T_34b53_row10_col1" class="data row10 col1" >0.111</td>
#       <td id="T_34b53_row10_col2" class="data row10 col2" >0.123</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row11" class="row_heading level1 row11" >ColBERT</th>
#       <td id="T_34b53_row11_col0" class="data row11 col0" >0.096*</td>
#       <td id="T_34b53_row11_col1" class="data row11 col1" >0.13*</td>
#       <td id="T_34b53_row11_col2" class="data row11 col2" >0.142*</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row12" class="row_heading level1 row12" >MonoT5</th>
#       <td id="T_34b53_row12_col0" class="data row12 col0" >0.09*</td>
#       <td id="T_34b53_row12_col1" class="data row12 col1" >0.121*</td>
#       <td id="T_34b53_row12_col2" class="data row12 col2" >0.131</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row13" class="row_heading level1 row13" >RRF</th>
#       <td id="T_34b53_row13_col0" class="data row13 col0" >0.085*</td>
#       <td id="T_34b53_row13_col1" class="data row13 col1" >0.113</td>
#       <td id="T_34b53_row13_col2" class="data row13 col2" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_34b53_level1_row14" class="row_heading level1 row14" >d2q</th>
#       <td id="T_34b53_row14_col0" class="data row14 col0" >0.092*</td>
#       <td id="T_34b53_row14_col1" class="data row14 col1" >0.128*</td>
#       <td id="T_34b53_row14_col2" class="data row14 col2" >0.14*</td>
#     </tr>
#   </tbody>
# </table>

# %%
table_ARP_statsig(df, dataset="trec-covid", subcollections=["round1", "round2", "round3", "round4", "round5"], highlight=True, mode="-core_queries")
# Out:
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# /home/jueri/dev/DCIR/evaluation/evaluate.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs_table["sorter"] = runs_table["method"].replace(sort_dict)
# <style type="text/css">
# #T_3b6e4_row2_col0, #T_3b6e4_row2_col1, #T_3b6e4_row3_col0, #T_3b6e4_row3_col3, #T_3b6e4_row3_col4, #T_3b6e4_row4_col2, #T_3b6e4_row7_col0, #T_3b6e4_row7_col1, #T_3b6e4_row7_col3, #T_3b6e4_row9_col2, #T_3b6e4_row9_col4, #T_3b6e4_row12_col0, #T_3b6e4_row12_col1, #T_3b6e4_row12_col2, #T_3b6e4_row13_col3, #T_3b6e4_row13_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_3b6e4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >subcollection</th>
#       <th id="T_3b6e4_level0_col0" class="col_heading level0 col0" >round1</th>
#       <th id="T_3b6e4_level0_col1" class="col_heading level0 col1" >round2</th>
#       <th id="T_3b6e4_level0_col2" class="col_heading level0 col2" >round3</th>
#       <th id="T_3b6e4_level0_col3" class="col_heading level0 col3" >round4</th>
#       <th id="T_3b6e4_level0_col4" class="col_heading level0 col4" >round5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >measure</th>
#       <th class="index_name level1" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b6e4_level0_row0" class="row_heading level0 row0" rowspan="5">ndcg</th>
#       <th id="T_3b6e4_level1_row0" class="row_heading level1 row0" >BM25</th>
#       <td id="T_3b6e4_row0_col0" class="data row0 col0" >0.421</td>
#       <td id="T_3b6e4_row0_col1" class="data row0 col1" >0.301</td>
#       <td id="T_3b6e4_row0_col2" class="data row0 col2" >0.334</td>
#       <td id="T_3b6e4_row0_col3" class="data row0 col3" >0.360</td>
#       <td id="T_3b6e4_row0_col4" class="data row0 col4" >0.309</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row1" class="row_heading level1 row1" >ColBERT</th>
#       <td id="T_3b6e4_row1_col0" class="data row1 col0" >0.389</td>
#       <td id="T_3b6e4_row1_col1" class="data row1 col1" >0.284</td>
#       <td id="T_3b6e4_row1_col2" class="data row1 col2" >0.321</td>
#       <td id="T_3b6e4_row1_col3" class="data row1 col3" >0.327</td>
#       <td id="T_3b6e4_row1_col4" class="data row1 col4" >0.298</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row2" class="row_heading level1 row2" >MonoT5</th>
#       <td id="T_3b6e4_row2_col0" class="data row2 col0" >0.439</td>
#       <td id="T_3b6e4_row2_col1" class="data row2 col1" >0.319</td>
#       <td id="T_3b6e4_row2_col2" class="data row2 col2" >0.344</td>
#       <td id="T_3b6e4_row2_col3" class="data row2 col3" >0.363</td>
#       <td id="T_3b6e4_row2_col4" class="data row2 col4" >0.319</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row3" class="row_heading level1 row3" >RRF</th>
#       <td id="T_3b6e4_row3_col0" class="data row3 col0" >0.439*</td>
#       <td id="T_3b6e4_row3_col1" class="data row3 col1" >0.316*</td>
#       <td id="T_3b6e4_row3_col2" class="data row3 col2" >0.340</td>
#       <td id="T_3b6e4_row3_col3" class="data row3 col3" >0.373*</td>
#       <td id="T_3b6e4_row3_col4" class="data row3 col4" >0.322*</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row4" class="row_heading level1 row4" >d2q</th>
#       <td id="T_3b6e4_row4_col0" class="data row4 col0" >0.435</td>
#       <td id="T_3b6e4_row4_col1" class="data row4 col1" >0.317</td>
#       <td id="T_3b6e4_row4_col2" class="data row4 col2" >0.345</td>
#       <td id="T_3b6e4_row4_col3" class="data row4 col3" >0.341*</td>
#       <td id="T_3b6e4_row4_col4" class="data row4 col4" >0.315</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level0_row5" class="row_heading level0 row5" rowspan="5">bpref</th>
#       <th id="T_3b6e4_level1_row5" class="row_heading level1 row5" >BM25</th>
#       <td id="T_3b6e4_row5_col0" class="data row5 col0" >0.369</td>
#       <td id="T_3b6e4_row5_col1" class="data row5 col1" >0.312</td>
#       <td id="T_3b6e4_row5_col2" class="data row5 col2" >0.357</td>
#       <td id="T_3b6e4_row5_col3" class="data row5 col3" >0.398</td>
#       <td id="T_3b6e4_row5_col4" class="data row5 col4" >0.340</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row6" class="row_heading level1 row6" >ColBERT</th>
#       <td id="T_3b6e4_row6_col0" class="data row6 col0" >0.372</td>
#       <td id="T_3b6e4_row6_col1" class="data row6 col1" >0.308</td>
#       <td id="T_3b6e4_row6_col2" class="data row6 col2" >0.356</td>
#       <td id="T_3b6e4_row6_col3" class="data row6 col3" >0.393</td>
#       <td id="T_3b6e4_row6_col4" class="data row6 col4" >0.331</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row7" class="row_heading level1 row7" >MonoT5</th>
#       <td id="T_3b6e4_row7_col0" class="data row7 col0" >0.401</td>
#       <td id="T_3b6e4_row7_col1" class="data row7 col1" >0.338*</td>
#       <td id="T_3b6e4_row7_col2" class="data row7 col2" >0.371</td>
#       <td id="T_3b6e4_row7_col3" class="data row7 col3" >0.410</td>
#       <td id="T_3b6e4_row7_col4" class="data row7 col4" >0.344</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row8" class="row_heading level1 row8" >RRF</th>
#       <td id="T_3b6e4_row8_col0" class="data row8 col0" >0.379</td>
#       <td id="T_3b6e4_row8_col1" class="data row8 col1" >0.325*</td>
#       <td id="T_3b6e4_row8_col2" class="data row8 col2" >0.362</td>
#       <td id="T_3b6e4_row8_col3" class="data row8 col3" >0.406</td>
#       <td id="T_3b6e4_row8_col4" class="data row8 col4" >0.350</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row9" class="row_heading level1 row9" >d2q</th>
#       <td id="T_3b6e4_row9_col0" class="data row9 col0" >0.39*</td>
#       <td id="T_3b6e4_row9_col1" class="data row9 col1" >0.328</td>
#       <td id="T_3b6e4_row9_col2" class="data row9 col2" >0.373</td>
#       <td id="T_3b6e4_row9_col3" class="data row9 col3" >0.401</td>
#       <td id="T_3b6e4_row9_col4" class="data row9 col4" >0.357</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level0_row10" class="row_heading level0 row10" rowspan="5">P\_10</th>
#       <th id="T_3b6e4_level1_row10" class="row_heading level1 row10" >BM25</th>
#       <td id="T_3b6e4_row10_col0" class="data row10 col0" >0.430</td>
#       <td id="T_3b6e4_row10_col1" class="data row10 col1" >0.177</td>
#       <td id="T_3b6e4_row10_col2" class="data row10 col2" >0.263</td>
#       <td id="T_3b6e4_row10_col3" class="data row10 col3" >0.253</td>
#       <td id="T_3b6e4_row10_col4" class="data row10 col4" >0.233</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row11" class="row_heading level1 row11" >ColBERT</th>
#       <td id="T_3b6e4_row11_col0" class="data row11 col0" >0.407</td>
#       <td id="T_3b6e4_row11_col1" class="data row11 col1" >0.200</td>
#       <td id="T_3b6e4_row11_col2" class="data row11 col2" >0.247</td>
#       <td id="T_3b6e4_row11_col3" class="data row11 col3" >0.167*</td>
#       <td id="T_3b6e4_row11_col4" class="data row11 col4" >0.163</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row12" class="row_heading level1 row12" >MonoT5</th>
#       <td id="T_3b6e4_row12_col0" class="data row12 col0" >0.483</td>
#       <td id="T_3b6e4_row12_col1" class="data row12 col1" >0.220</td>
#       <td id="T_3b6e4_row12_col2" class="data row12 col2" >0.310</td>
#       <td id="T_3b6e4_row12_col3" class="data row12 col3" >0.237</td>
#       <td id="T_3b6e4_row12_col4" class="data row12 col4" >0.187</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row13" class="row_heading level1 row13" >RRF</th>
#       <td id="T_3b6e4_row13_col0" class="data row13 col0" >0.453</td>
#       <td id="T_3b6e4_row13_col1" class="data row13 col1" >0.190</td>
#       <td id="T_3b6e4_row13_col2" class="data row13 col2" >0.267</td>
#       <td id="T_3b6e4_row13_col3" class="data row13 col3" >0.277</td>
#       <td id="T_3b6e4_row13_col4" class="data row13 col4" >0.243</td>
#     </tr>
#     <tr>
#       <th id="T_3b6e4_level1_row14" class="row_heading level1 row14" >d2q</th>
#       <td id="T_3b6e4_row14_col0" class="data row14 col0" >0.407</td>
#       <td id="T_3b6e4_row14_col1" class="data row14 col1" >0.200</td>
#       <td id="T_3b6e4_row14_col2" class="data

# %% [markdown]
# # Long

# %%
table_ARP_full(long, highlight=True, save=False)
# Out:
# <style type="text/css">
# #T_acc3a_row1_col8, #T_acc3a_row1_col9, #T_acc3a_row1_col10, #T_acc3a_row2_col0, #T_acc3a_row2_col1, #T_acc3a_row2_col2, #T_acc3a_row2_col3, #T_acc3a_row2_col4, #T_acc3a_row2_col5, #T_acc3a_row3_col6, #T_acc3a_row3_col7, #T_acc3a_row4_col0, #T_acc3a_row6_col8, #T_acc3a_row6_col9, #T_acc3a_row6_col10, #T_acc3a_row7_col1, #T_acc3a_row7_col2, #T_acc3a_row7_col3, #T_acc3a_row7_col4, #T_acc3a_row7_col6, #T_acc3a_row9_col0, #T_acc3a_row9_col5, #T_acc3a_row9_col7, #T_acc3a_row12_col1, #T_acc3a_row12_col2, #T_acc3a_row12_col3, #T_acc3a_row12_col4, #T_acc3a_row13_col3, #T_acc3a_row13_col6, #T_acc3a_row13_col7, #T_acc3a_row14_col0, #T_acc3a_row14_col5, #T_acc3a_row14_col8, #T_acc3a_row14_col9, #T_acc3a_row14_col10 {
#   font-weight: bold;
# }
# </style>
# <table id="T_acc3a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_acc3a_level0_col0" class="col_heading level0 col0" colspan="3">longeval</th>
#       <th id="T_acc3a_level0_col3" class="col_heading level0 col3" colspan="5">trec-covid</th>
#       <th id="T_acc3a_level0_col8" class="col_heading level0 col8" colspan="3">tripclick-test-head</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >subcollection</th>
#       <th id="T_acc3a_level1_col0" class="col_heading level1 col0" >LT</th>
#       <th id="T_acc3a_level1_col1" class="col_heading level1 col1" >ST</th>
#       <th id="T_acc3a_level1_col2" class="col_heading level1 col2" >WT</th>
#       <th id="T_acc3a_level1_col3" class="col_heading level1 col3" >round1</th>
#       <th id="T_acc3a_level1_col4" class="col_heading level1 col4" >round2</th>
#       <th id="T_acc3a_level1_col5" class="col_heading level1 col5" >round3</th>
#       <th id="T_acc3a_level1_col6" class="col_heading level1 col6" >round4</th>
#       <th id="T_acc3a_level1_col7" class="col_heading level1 col7" >round5</th>
#       <th id="T_acc3a_level1_col8" class="col_heading level1 col8" >t1</th>
#       <th id="T_acc3a_level1_col9" class="col_heading level1 col9" >t2</th>
#       <th id="T_acc3a_level1_col10" class="col_heading level1 col10" >t3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >measure</th>
#       <th class="index_name level1" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acc3a_level0_row0" class="row_heading level0 row0" rowspan="5">P\_10</th>
#       <th id="T_acc3a_level1_row0" class="row_heading level1 row0" >BM25</th>
#       <td id="T_acc3a_row0_col0" class="data row0 col0" >0.110</td>
#       <td id="T_acc3a_row0_col1" class="data row0 col1" >0.086</td>
#       <td id="T_acc3a_row0_col2" class="data row0 col2" >0.100</td>
#       <td id="T_acc3a_row0_col3" class="data row0 col3" >0.430</td>
#       <td id="T_acc3a_row0_col4" class="data row0 col4" >0.177</td>
#       <td id="T_acc3a_row0_col5" class="data row0 col5" >0.263</td>
#       <td id="T_acc3a_row0_col6" class="data row0 col6" >0.253</td>
#       <td id="T_acc3a_row0_col7" class="data row0 col7" >0.233</td>
#       <td id="T_acc3a_row0_col8" class="data row0 col8" >0.081</td>
#       <td id="T_acc3a_row0_col9" class="data row0 col9" >0.111</td>
#       <td id="T_acc3a_row0_col10" class="data row0 col10" >0.123</td>
#     </tr>
#     <tr>
#       <th id="T_acc3a_level1_row1" class="row_heading level1 row1" >ColBERT</th>
#       <td id="T_acc3a_row1_col0" class="data row1 col0" >0.119</td>
#       <td id="T_acc3a_row1_col1" class="data row1 col1" >0.092</td>
#       <td id="T_acc3a_row1_col2" class="data row1 col2" >0.102</td>
#       <td id="T_acc3a_row1_col3" class="data row1 col3" >0.407</td>
#       <td id="T_acc3a_row1_col4" class="data row1 col4" >0.200</td>
#       <td id="T_acc3a_row1_col5" class="data row1 col5" >0.247</td>
#       <td id="T_acc3a_row1_col6" class="data row1 col6" >0.167</td>
#       <td id="T_acc3a_row1_col7" class="data row1 col7" >0.163</td>
#       <td id="T_acc3a_row1_col8" class="data row1 col8" >0.096</td>
#       <td id="T_acc3a_row1_col9" class="data row1 col9" >0.130</td>
#       <td id="T_acc3a_row1_col10" class="data row1 col10" >0.142</td>
#     </tr>
#     <tr>
#       <th id="T_acc3a_level1_row2" class="row_heading level1 row2" >MonoT5</th>
#       <td id="T_acc3a_row2_col0" class="data row2 col0" >0.123</td>
#       <td id="T_acc3a_row2_col1" class="data row2 col1" >0.106</td>
#       <td id="T_acc3a_row2_col2" class="data row2 col2" >0.113</td>
#       <td id="T_acc3a_row2_col3" class="data row2 col3" >0.483</td>
#       <td id="T_acc3a_row2_col4" class="data row2 col4" >0.220</td>
#       <td id="T_acc3a_row2_col5" class="data row2 col5" >0.310</td>
#       <td id="T_acc3a_row2_col6" class="data row2 col6" >0.237</td>
#       <td id="T_acc3a_row2_col7" class="data row2 col7" >0.187</td>
#       <td id="T_acc3a_row2_col8" class="data row2 col8" >0.090</td>
#       <td id="T_acc3a_row2_col9" class="data row2 col9" >0.121</td>
#       <td id="T_acc3a_row2_col10" class="data row2 col10" >0.131</td>
#     </tr>
#     <tr>
#       <th id="T_acc3a_level1_row3" class="row_heading level1 row3" >RRF</th>
#       <td id="T_acc3a_row3_col0" class="data row3 col0" >0.121</td>
#       <td id="T_acc3a_row3_col1" class="data row3 col1" >0.089</td>
#       <td id="T_acc3a_row3_col2" class="data row3 col2" >0.106</td>
#       <td id="T_acc3a_row3_col3" class="data row3 col3" >0.453</td>
#       <td id="T_acc3a_row3_col4" class="data row3 col4" >0.190</td>
#       <td id="T_acc3a_row3_col5" class="data row3 col5" >0.267</td>
#       <td id="T_acc3a_row3_col6" class="data row3 col6" >0.277</td>
#       <td id="T_acc3a_row3_col7" class="data row3 col7" >0.243</td>
#       <td id="T_acc3a_row3_col8" class="data row3 col8" >0.085</td>
#       <td id="T_acc3a_row3_col9" class="data row3 col9" >0.113</td>
#       <td id="T_acc3a_row3_col10" class="data row3 col10" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_acc3a_level1_row4" class="row_heading level1 row4" >d2q</th>
#       <td id="T_acc3a_row4_col0" class="data row4 col0" >0.123</td>
#       <td id="T_acc3a_row4_col1" class="data row4 col1" >0.102</td>
#       <td id="T_acc3a_row4_col2" class="data row4 col2" >0.111</td>
#       <td id="T_acc3a_row4_col3" class="data row4 col3" >0.407</td>
#       <td id="T_acc3a_row4_col4" class="data row4 col4" >0.200</td>
#       <td id="T_acc3a_row4_col5" class="data row4 col5" >0.277</td>
#       <td id="T_acc3a_row4_col6" class="data row4 col6" >0.183</td>
#       <td id="T_acc3a_row4_col7" class="data row4 col7" >0.190</td>
#       <td id="T_acc3a_row4_col8" class="data row4 col8" >0.092</td>
#       <td id="T_acc3a_row4_col9" class="data row4 col9" >0.128</td>
#       <td id="T_acc3a_row4_col10" class="data row4 col10" >0.140</td>
#     </tr>
#     <tr>
#       <th id="T_acc3a_level0_row5" class="row_heading level0 row5" rowspan="5">bpref</th>
#       <th id="T_acc3a_level1_row5" class="row_heading level1 row5" >BM25</th>
#       <td id="T_acc3a_row5_col0" class="data row5 col0" >0.329</td>
#       <td id="T_acc3a_row5_col1" class="data row5 col1" >0.315</td>
#       <td id="T_acc3a_row5_col2" class="data row5 col2" >0.327</td>
#       <td id="T_acc3a_row5_col3" class="data row5 col3" >0.369</td>
#       <td id="T_acc3a_row5_col4" class="data row5 col4" >0.312</td>
#       <td id="T_acc3a_row5_col5" class="data row5 col5" >0.357</td>
#       <td id="T_acc3a_row5_col6" class="data row5 col6" >0.398</td>
#       <td id="T_acc3a_row5_col7" class="data row5 col7" >0.340</td>
#       <td id="T_acc3a_row5_col8" class="data row5 col8" >0.405</td>
#       <td id="T_acc3a_row5_col9" class="data row5 col9" >0.350</td>
#       <td id="T_acc3a_row5_col10" class="d

# %%
table_RD_DRI(long, highlight=True, save=False)
# Out:
# <style type="text/css">
# #T_c8ee6_row0_col0, #T_c8ee6_row0_col1, #T_c8ee6_row0_col4, #T_c8ee6_row0_col5, #T_c8ee6_row1_col2, #T_c8ee6_row1_col3, #T_c8ee6_row2_col8, #T_c8ee6_row2_col9, #T_c8ee6_row2_col10, #T_c8ee6_row2_col11, #T_c8ee6_row3_col4, #T_c8ee6_row3_col5, #T_c8ee6_row3_col6, #T_c8ee6_row3_col7, #T_c8ee6_row3_col12, #T_c8ee6_row3_col13, #T_c8ee6_row3_col14, #T_c8ee6_row3_col15, #T_c8ee6_row4_col14, #T_c8ee6_row4_col15, #T_c8ee6_row5_col2, #T_c8ee6_row5_col3, #T_c8ee6_row6_col4, #T_c8ee6_row6_col5, #T_c8ee6_row6_col8, #T_c8ee6_row6_col9, #T_c8ee6_row6_col10, #T_c8ee6_row6_col11, #T_c8ee6_row6_col12, #T_c8ee6_row6_col13, #T_c8ee6_row7_col0, #T_c8ee6_row7_col1, #T_c8ee6_row7_col6, #T_c8ee6_row7_col7, #T_c8ee6_row8_col5, #T_c8ee6_row8_col6, #T_c8ee6_row8_col7, #T_c8ee6_row8_col10, #T_c8ee6_row8_col11, #T_c8ee6_row9_col2, #T_c8ee6_row9_col3, #T_c8ee6_row10_col8, #T_c8ee6_row10_col9, #T_c8ee6_row11_col0, #T_c8ee6_row11_col1, #T_c8ee6_row11_col4, #T_c8ee6_row11_col12, #T_c8ee6_row11_col13, #T_c8ee6_row11_col14, #T_c8ee6_row11_col15 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c8ee6_row0_col2 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_c8ee6_row0_col3 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_c8ee6_row0_col6 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col7, #T_c8ee6_row3_col9 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col8, #T_c8ee6_row0_col9, #T_c8ee6_row1_col0, #T_c8ee6_row1_col1, #T_c8ee6_row1_col10, #T_c8ee6_row1_col11, #T_c8ee6_row1_col14, #T_c8ee6_row1_col15, #T_c8ee6_row2_col2, #T_c8ee6_row2_col3, #T_c8ee6_row2_col4, #T_c8ee6_row2_col5, #T_c8ee6_row2_col6, #T_c8ee6_row2_col7, #T_c8ee6_row2_col12, #T_c8ee6_row2_col13, #T_c8ee6_row4_col4, #T_c8ee6_row4_col5, #T_c8ee6_row5_col0, #T_c8ee6_row5_col1, #T_c8ee6_row5_col6, #T_c8ee6_row5_col7, #T_c8ee6_row5_col8, #T_c8ee6_row5_col9, #T_c8ee6_row5_col10, #T_c8ee6_row5_col11, #T_c8ee6_row5_col12, #T_c8ee6_row5_col13, #T_c8ee6_row6_col2, #T_c8ee6_row6_col3, #T_c8ee6_row7_col14, #T_c8ee6_row7_col15, #T_c8ee6_row8_col2, #T_c8ee6_row8_col3, #T_c8ee6_row8_col12, #T_c8ee6_row8_col13, #T_c8ee6_row8_col14, #T_c8ee6_row8_col15, #T_c8ee6_row9_col0, #T_c8ee6_row9_col1, #T_c8ee6_row10_col4, #T_c8ee6_row10_col5, #T_c8ee6_row10_col6, #T_c8ee6_row10_col7, #T_c8ee6_row11_col8, #T_c8ee6_row11_col9, #T_c8ee6_row11_col10, #T_c8ee6_row11_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col10 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col11 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col12, #T_c8ee6_row1_col12 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col13 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_c8ee6_row0_col14, #T_c8ee6_row5_col15 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_c8ee6_row0_col15, #T_c8ee6_row1_col9 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_c8ee6_row1_col4 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_c8ee6_row1_col5 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_c8ee6_row1_col6 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_c8ee6_row1_col7 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_c8ee6_row1_col8 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_c8ee6_row1_col13, #T_c8ee6_row4_col1 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_c8ee6_row2_col0 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_c8ee6_row2_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_c8ee6_row2_col14 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_c8ee6_row2_col15 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_c8ee6_row3_col0, #T_c8ee6_row10_col11 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_c8ee6_row3_col1 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_c8ee6_row3_col2 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_c8ee6_row3_col3 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_c8ee6_row3_col8 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_c8ee6_row3_col10 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_c8ee6_row3_col11 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_c8ee6_row4_col0 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_c8ee6_row4_col2 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_c8ee6_row4_col3 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_c8ee6_row4_col6, #T_c8ee6_row6_col6 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_c8ee6_row4_col7, #T_c8ee6_row6_col7, #T_c8ee6_row7_col2 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_c8ee6_row4_col8 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_c8ee6_row4_col9, #T_c8ee6_row9_col4, #T_c8ee6_row9_col8 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_c8ee6_row4_col10, #T_c8ee6_row5_col5 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_c8ee6_row4_col11 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_c8ee6_row4_col12 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_c8ee6_row4_col13 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_c8ee6_row5_col4, #T_c8ee6_row9_col5 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_c8ee6_row5_col14 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_c8ee6_row6_col0 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_c8ee6_row6_col1 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_c8ee6_row6_col14 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_c8ee6_row6_col15 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_c8ee6_row7_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_c8ee6_row7_col4, #T_c8ee6_row7_col5 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_c8ee6_row7_col8 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_c8ee6_row7_col9 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_c8ee6_row7_col10, #T_c8ee6_row7_col11 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_c8ee6_row7_col12 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_c8ee6_row7_col13 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_c8ee6_row8_col0, #T_c8ee6_row11_col6 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_c8ee6_row8_col1 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_c8ee6_row8_col4 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_c8ee6_row8_col8 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_c8ee6_row8_col9 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_c8ee6_row9_col6 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_c8ee6_row9_col7 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_c8ee6_row9_col9 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_c8ee6_row9_col10, #T_c8ee6_row9_col11 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_c8ee6_row9_col12 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_c8ee6_row9_col13 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_c8ee6_row9_col14 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_c8ee6_row9_col15 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_c8ee6_row10_col0, #T_c8ee6_row10_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_c8ee6_row10_col2, #T_c8ee6_row10_col3 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_c8ee6_row10_col10 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_c8ee6_row10_col12 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_c8ee6_row10_col13 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_c8ee6_row10_col14 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_c8ee6_row10_col15 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_c8ee6_row11_col2 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_c8ee6_row11_col3 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_c8ee6_row11_col5 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_c8ee6_row11_col7 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c8ee6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_c8ee6_level0_col0" class="col_

# %%
d
# Out:
# group                             ARP                   RD                \
# measure                          P_10  bpref   ndcg   P_10  bpref   ndcg
# dataset  subcollection method
# longeval ST            ColBERT  0.092   0.32  0.274  0.095  0.044  0.042
#                        MonoT5   0.106  0.346  0.302  0.057  0.019   0.02
#                        RRF      0.089  0.328  0.282  0.167  0.062  0.035
#                        d2q      0.102  0.335  0.287  0.087  0.021  0.034
#          LT            ColBERT  0.119  0.343  0.298 -0.175 -0.023 -0.042
#                        MonoT5   0.123  0.342  0.311 -0.093  0.029 -0.009
#                        RRF      0.121  0.352  0.315 -0.136 -0.005 -0.078
#                        d2q      0.123  0.374  0.327 -0.109 -0.093 -0.101
#
# group                             DRI                   ER                \
# measure                          P_10  bpref   ndcg   P_10  bpref   ndcg
# dataset  subcollection method
# longeval ST            ColBERT -0.049  0.008   0.01    3.5  0.663   0.32
#                        MonoT5  -0.105  -0.02 -0.015  1.563  1.213  1.119
#                        RRF      0.036  0.028  0.002  0.375  0.584  0.901
#                        d2q     -0.065 -0.017  0.001  1.357  1.315  0.942
#          LT            ColBERT -0.064 -0.019  0.041    5.5  1.761 -1.956
#                        MonoT5   0.012  0.037  0.077    1.0  0.527  0.202
#                        RRF      -0.03   -0.0  0.008  1.625  1.006  0.854
#                        d2q     -0.004 -0.091 -0.015  1.143  2.941  1.379
#
# group                            RMSE                   RBO
# measure                          P_10  bpref   ndcg rbo_100
# dataset  subcollection method
# longeval ST            ColBERT  0.065  0.137  0.141   0.593
#                        MonoT5   0.077  0.176  0.138   0.594
#                        RRF       0.06  0.166  0.127   0.579
#                        d2q      0.076  0.159  0.166   0.539
#          LT            ColBERT   0.07  0.144  0.137   0.583
#                        MonoT5   0.075  0.181  0.135   0.602
#                        RRF      0.071  0.165  0.129   0.544
#                        d2q      0.075  0.151   0.16   0.552

# %%
dataset = "longeval"
MEASURES =["ndcg", "bpref", "P_10", "rbo_100"]

from matplotlib import colors
import seaborn as sns
import matplotlib.pyplot as plt

### Final table

##### sorter
def sorter_dataset(x):
    sorted_datasets = {"longeval": 1, "trec-covid": 3, "tripclick-test-head":2}
    x = [sorted_datasets.get(a) for a in x]
    return x

def sorter_subcollections(x):
    sorted_subcollections = {"ST": 1, "LT": 2}
    x = [sorted_subcollections.get(a, a) for a in x]
    return x

def sorter_measures(x):
    sorted_measures = {"P_10": 1, "bpref": 2, "ndcg": 3}
    x = [sorted_measures.get(a) for a in x]
    return x

def sorter_group(x):
    sorted = {"ARP": 1, "RD": 2, "DRI":3, "ER":4, "RBO":6, "RMSE":5}
    x = [sorted.get(a, a) for a in x]
    return x


#### styler
def b_abs(s):
    max_val = max(s.max(), abs(s.min()))
    norm = colors.Normalize(0, max_val)
    normed = norm(abs(s.values))

    style = []
    for val in abs(normed):
        c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
        if val < max(normed)*0.4:
            text = "white"
        else:
            text = "black"
        style.append(f"background-color: {c}; color: {text}")
    return style

def b_pos(s):
    max_val = max(s.max(), abs(s.min()))
    norm = colors.Normalize()
    normed = norm(list(abs(s.values)))
    
    style = []
    for val in normed:
        c = colors.rgb2hex(plt.colormaps["Greens"](val))
        if val < max(normed)*0.4:
            text = "black"
        else:
            text = "white"
        style.append(f"background-color: {c}; color: {text}")

    return style

def b_one(s):
    dist = abs(abs(s.values) -1)
    max_val = max(max(dist), min(dist))
    norm = colors.Normalize(min(dist), max_val)
    normed = norm(dist)
    
    style = []
    for val in normed:
        c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
        if val > max(normed)*0.5:
            text = "black"
        else:
            text = "white"
        style.append(f"background-color: {c}; color: {text}")
    return style


def higher_better_zero_one(s):
    norm = colors.Normalize(min(s),max(s))
    normed = norm(s)
    style = []
    for val in normed:
        c = colors.rgb2hex(plt.colormaps["Greens"](val))
        if val < 0.6:
            text = "black"
        else:
            text = "white"
        style.append(f"background-color: {c}; color: {text}")
    return style


def closser_to_zero_better(s):
    dist = abs(s)
    norm = colors.Normalize(min(dist), max(dist))
    normed = norm(dist)
    style = []
    for val in normed:
        c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
        if val > 0.6:
            text = "black"
        else:
            text = "white"
        style.append(f"background-color: {c}; color: {text}")
    return style


def closser_to_one_better(s):
    dist = abs(s-1)
    max_val = max(max(dist), min(dist))
    norm = colors.Normalize(min(dist), max_val)
    normed = norm(dist)
    style = []
    for val in normed:
        c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
        if val > 0.6:
            text = "black"
        else:
            text = "white"
        style.append(f"background-color: {c}; color: {text}")
    return style





def lower_better(s):
    dist = abs(s)
    norm = colors.Normalize(min(dist), max(dist))
    normed = norm(dist)
    style = []
    for val in normed:
        c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
        if val > 0.6:
            text = "black"
        else:
            text = "white"
        style.append(f"background-color: {c}; color: {text}")
    return style


# data
d = long
d = d[(d["group"].isin(["ARP", "RD", "DRI", "ER", "RBO", "RMSE"])) & (d["measure"].isin(MEASURES)) & (d["method"]!= "BM25") & (~d["subcollection"].isin(["WT", "t1", "round1"]))]
d = d.pivot(index=["dataset", "subcollection", "method"], columns=["group", "measure"], values="value")
d = d.sort_index(level=0, key=sorter_dataset).sort_index(level=1, key=sorter_subcollections)
d = d.sort_index(axis=1, level=0, key=sorter_group)#.sort_index(axis=1, level=1, key=sorter_measures)


# styling
highlight = True
if highlight:
    df_styled = d.style.format(precision=3).format_index(escape="latex")
    
    for index in d.index.levels[0]:
        for col in d.columns:
            if col[0] in ["DRI"]:
                # break
                df_styled = df_styled.apply(closser_to_zero_better, subset=(index, col))
            if col[0] in ["ER"]:
                df_styled = df_styled.apply(closser_to_one_better, subset=(index, col))
                # df_styled = df_styled.apply(closser_to_one_better, subset=(d.index.get_loc_level(index[1], level=1)[0], col))
            if col[0] in ["RD", "RMSE"]:
                df_styled = df_styled.apply(lower_better, subset=(index, col))
            if col[0] in ["RBO", "ARP"]:
                df_styled = df_styled.apply(higher_better_zero_one, subset=(index, col))

df_styled

df_styled.to_latex(f"../../../paper/ECIR23/tables/results.tex", convert_css=True)

# for index in df.index.levels[0]:
#     for col in df.columns:
#         if col[2] in ["ER", "DRI"]:
#             df_styled = df_styled.apply(b_abs, subset=(index, col))

# %%
import numpy as np

# %%
o = np.array([-1, 0.8, 1, 1.5, -0.2])
o
# Out:
# array([-1. ,  0.8,  1. ,  1.5, -0.2])

# %%
abs(o) 

# dist = abs(abs(s)-1)
# max_val = max(max(dist), min(dist))
# Out:
# array([1. , 0.8, 1. , 1.5, 0.2])

# %%
o-1
# Out:
# array([-2. , -0.2,  0. ,  0.5, -1.2])

# %%
df_styled
# Out:
# <style type="text/css">
# #T_89719_row0_col0, #T_89719_row15_col15, #T_89719_row22_col13 {
#   background-color: #ebf7e7;
#   color: black;
# }
# #T_89719_row0_col1, #T_89719_row0_col2, #T_89719_row1_col6, #T_89719_row1_col12, #T_89719_row2_col0, #T_89719_row3_col14, #T_89719_row3_col15, #T_89719_row4_col3, #T_89719_row4_col9, #T_89719_row4_col11, #T_89719_row5_col8, #T_89719_row5_col13, #T_89719_row7_col4, #T_89719_row7_col5, #T_89719_row7_col7, #T_89719_row7_col10, #T_89719_row8_col1, #T_89719_row8_col2, #T_89719_row8_col4, #T_89719_row10_col5, #T_89719_row16_col9, #T_89719_row17_col11, #T_89719_row19_col8, #T_89719_row20_col0, #T_89719_row20_col10, #T_89719_row21_col3, #T_89719_row21_col6, #T_89719_row21_col7, #T_89719_row21_col12, #T_89719_row21_col13, #T_89719_row23_col14, #T_89719_row23_col15, #T_89719_row24_col8, #T_89719_row26_col0, #T_89719_row26_col2, #T_89719_row26_col9, #T_89719_row26_col10, #T_89719_row26_col11, #T_89719_row28_col7, #T_89719_row28_col12, #T_89719_row29_col6, #T_89719_row30_col1, #T_89719_row31_col3, #T_89719_row31_col4, #T_89719_row31_col5, #T_89719_row31_col13, #T_89719_row31_col14, #T_89719_row31_col15 {
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_89719_row0_col3 {
#   background-color: #349d53;
#   color: white;
# }
# #T_89719_row0_col4, #T_89719_row15_col5 {
#   background-color: #5db96b;
#   color: white;
# }
# #T_89719_row0_col5, #T_89719_row0_col14, #T_89719_row4_col5, #T_89719_row7_col11, #T_89719_row9_col6 {
#   background-color: #3da65a;
#   color: white;
# }
# #T_89719_row0_col6, #T_89719_row20_col8 {
#   background-color: #5eb96b;
#   color: white;
# }
# #T_89719_row0_col7, #T_89719_row15_col10, #T_89719_row19_col1, #T_89719_row27_col8 {
#   background-color: #006027;
#   color: white;
# }
# #T_89719_row0_col8, #T_89719_row1_col5, #T_89719_row4_col0, #T_89719_row24_col4 {
#   background-color: #006b2b;
#   color: white;
# }
# #T_89719_row0_col9, #T_89719_row8_col11 {
#   background-color: #88ce87;
#   color: white;
# }
# #T_89719_row0_col10, #T_89719_row17_col5 {
#   background-color: #0c7735;
#   color: white;
# }
# #T_89719_row0_col11 {
#   background-color: #b6e2af;
#   color: black;
# }
# #T_89719_row0_col12 {
#   background-color: #2e964d;
#   color: white;
# }
# #T_89719_row0_col13, #T_89719_row1_col3, #T_89719_row2_col12, #T_89719_row2_col14, #T_89719_row3_col8, #T_89719_row3_col11, #T_89719_row5_col0, #T_89719_row5_col5, #T_89719_row5_col9, #T_89719_row5_col15, #T_89719_row6_col4, #T_89719_row6_col7, #T_89719_row6_col10, #T_89719_row7_col0, #T_89719_row7_col1, #T_89719_row7_col2, #T_89719_row7_col6, #T_89719_row8_col9, #T_89719_row8_col10, #T_89719_row8_col12, #T_89719_row8_col14, #T_89719_row9_col11, #T_89719_row9_col13, #T_89719_row9_col15, #T_89719_row11_col9, #T_89719_row12_col6, #T_89719_row13_col0, #T_89719_row15_col3, #T_89719_row15_col8, #T_89719_row17_col1, #T_89719_row17_col4, #T_89719_row18_col2, #T_89719_row18_col5, #T_89719_row18_col9, #T_89719_row22_col7, #T_89719_row24_col1, #T_89719_row24_col5, #T_89719_row24_col7, #T_89719_row24_col10, #T_89719_row25_col10, #T_89719_row25_col11, #T_89719_row25_col13, #T_89719_row25_col14, #T_89719_row25_col15, #T_89719_row26_col3, #T_89719_row26_col4, #T_89719_row26_col14, #T_89719_row27_col6, #T_89719_row27_col10, #T_89719_row27_col12, #T_89719_row28_col0, #T_89719_row28_col10, #T_89719_row29_col8, #T_89719_row29_col9, #T_89719_row29_col10, #T_89719_row31_col2, #T_89719_row31_col10 {
#   background-color: #00441b;
#   color: white;
# }
# #T_89719_row0_col15, #T_89719_row10_col11 {
#   background-color: #05712f;
#   color: white;
# }
# #T_89719_row1_col0, #T_89719_row17_col0 {
#   background-color: #73c476;
#   color: black;
# }
# #T_89719_row1_col1, #T_89719_row16_col2 {
#   background-color: #7ac77b;
#   color: black;
# }
# #T_89719_row1_col2, #T_89719_row14_col1 {
#   background-color: #68be70;
#   color: black;
# }
# #T_89719_row1_col4, #T_89719_row3_col10, #T_89719_row4_col13, #T_89719_row10_col9, #T_89719_row15_col9 {
#   background-color: #097532;
#   color: white;
# }
# #T_89719_row1_col7 {
#   background-color: #1a843f;
#   color: white;
# }
# #T_89719_row1_col8, #T_89719_row3_col7, #T_89719_row7_col8, #T_89719_row9_col8 {
#   background-color: #117b38;
#   color: white;
# }
# #T_89719_row1_col9, #T_89719_row1_col15, #T_89719_row15_col4, #T_89719_row24_col3 {
#   background-color: #006d2c;
#   color: white;
# }
# #T_89719_row1_col10, #T_89719_row26_col13 {
#   background-color: #006729;
#   color: white;
# }
# #T_89719_row1_col11, #T_89719_row9_col9, #T_89719_row16_col5, #T_89719_row18_col8, #T_89719_row31_col0 {
#   background-color: #005a24;
#   color: white;
# }
# #T_89719_row1_col13, #T_89719_row16_col6 {
#   background-color: #e7f6e2;
#   color: black;
# }
# #T_89719_row1_col14, #T_89719_row2_col5, #T_89719_row24_col9, #T_89719_row30_col11 {
#   background-color: #2b934b;
#   color: white;
# }
# #T_89719_row2_col1 {
#   background-color: #e0f3db;
#   color: black;
# }
# #T_89719_row2_col2 {
#   background-color: #dff3da;
#   color: black;
# }
# #T_89719_row2_col3, #T_89719_row8_col5 {
#   background-color: #edf8ea;
#   color: black;
# }
# #T_89719_row2_col4, #T_89719_row6_col12, #T_89719_row17_col3, #T_89719_row21_col1 {
#   background-color: #a8dca2;
#   color: black;
# }
# #T_89719_row2_col6, #T_89719_row7_col13, #T_89719_row18_col4 {
#   background-color: #339c52;
#   color: white;
# }
# #T_89719_row2_col7, #T_89719_row5_col3, #T_89719_row15_col6 {
#   background-color: #309950;
#   color: white;
# }
# #T_89719_row2_col8 {
#   background-color: #00481d;
#   color: white;
# }
# #T_89719_row2_col9, #T_89719_row6_col9, #T_89719_row10_col10, #T_89719_row12_col4, #T_89719_row13_col6, #T_89719_row14_col4 {
#   background-color: #03702e;
#   color: white;
# }
# #T_89719_row2_col10, #T_89719_row16_col4 {
#   background-color: #18823d;
#   color: white;
# }
# #T_89719_row2_col11, #T_89719_row10_col15, #T_89719_row13_col9, #T_89719_row19_col4, #T_89719_row21_col9 {
#   background-color: #005221;
#   color: white;
# }
# #T_89719_row2_col13, #T_89719_row31_col11 {
#   background-color: #abdda5;
#   color: black;
# }
# #T_89719_row2_col15, #T_89719_row22_col4 {
#   background-color: #3fa85b;
#   color: white;
# }
# #T_89719_row3_col0 {
#   background-color: #9fd899;
#   color: black;
# }
# #T_89719_row3_col1 {
#   background-color: #bee5b8;
#   color: black;
# }
# #T_89719_row3_col2, #T_89719_row29_col14, #T_89719_row30_col14 {
#   background-color: #c9eac2;
#   color: black;
# }
# #T_89719_row3_col3, #T_89719_row4_col14, #T_89719_row6_col6, #T_89719_row25_col5 {
#   background-color: #248c46;
#   color: white;
# }
# #T_89719_row3_col4, #T_89719_row10_col7 {
#   background-color: #107a37;
#   color: white;
# }
# #T_89719_row3_col5, #T_89719_row5_col4, #T_89719_row27_col3, #T_89719_row27_col11 {
#   background-color: #289049;
#   color: white;
# }
# #T_89719_row3_col6, #T_89719_row20_col12, #T_89719_row24_col11 {
#   background-color: #99d595;
#   color: black;
# }
# #T_89719_row3_col9, #T_89719_row5_col6, #T_89719_row10_col14, #T_89719_row11_col12, #T_89719_row23_col10, #T_89719_row30_col9 {
#   background-color: #005e26;
#   color: white;
# }
# #T_89719_row3_col12, #T_89719_row11_col5, #T_89719_row28_col4 {
#   background-color: #eff9eb;
#   color: black;
# }
# #T_89719_row3_col13, #T_89719_row13_col5, #T_89719_row19_col10 {
#   background-color: #75c477;
#   color: white;
# }
# #T_89719_row4_col1, #T_89719_row22_col2 {
#   background-color: #8ed08b;
#   color: black;
# }
# #T_89719_row4_col2 {
#   background-color: #86cc85;
#   color: black;
# }
# #T_89719_row4_col4, #T_89719_row5_col14 {
#   background-color: #16803c;
#   color: white;
# }
# #T_89719_row4_col6 {
#   background-color: #97d492;
#   color: white;
# }
# #T_89719_row4_col7, #T_89719_row22_col9 {
#   background-color: #17813d;
#   color: white;
# }
# #T_89719_row4_col8 {
#   background-color: #7dc87e;
#   color: white;
# }
# #T_89719_row4_col10, #T_89719_row23_col6 {
#   background-color: #46ae60;
#   color: white;
# }
# #T_89719_row4_col12, #T_89719_row14_col5 {
#   background-color: #94d390;
#   color: white;
# }
# #T_89719_row4_col15, #T_89719_row5_col2, #T_89719_row27_col14 {
#   background-color: #2f984f;
#   color: white;
# }
# #T_89719_row5_col1 {
#   background-color: #95d391;
#   color: black;
# }
# #T_89719_row5_col7, #T_89719_row23_col4 {
#   background-color: #4eb264;
#   color: white;
# }
# #T_89719_row5_col10 {

# %%
from matplotlib import colors
import seaborn as sns
import matplotlib.pyplot as plt

def table_RD_DRI(long, dataset, highlight=True, save=False):

    def b_abs(s):
        max_val = max(s.max(), abs(s.min()))
        norm = colors.Normalize(0, max_val)
        normed = norm(abs(s.values))

        style = []
        for val in abs(normed):
            c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
            if val < max(normed)*0.4:
                text = "white"
            else:
                text = "black"
            style.append(f"background-color: {c}; color: {text}")
        return style

    def b_pos(s):
        max_val = max(s.max(), abs(s.min()))
        norm = colors.Normalize()
        normed = norm(abs(s.values))
        
        style = []
        for val in normed:
            c = colors.rgb2hex(plt.colormaps["Greens"](val))
            if val < max(normed)*0.4:
                text = "black"
            else:
                text = "white"
            style.append(f"background-color: {c}; color: {text}")

        return style

    def b_one(s):
        dist = abs(abs(s.values) -1)
        max_val = max(max(dist), min(dist))
        norm = colors.Normalize(min(dist), max_val)
        normed = norm(dist)
        
        style = []
        for val in normed:
            c = colors.rgb2hex(plt.colormaps["Greens"].reversed()(val))
            if val > max(normed)*0.5:
                text = "black"
            else:
                text = "white"
            style.append(f"background-color: {c}; color: {text}")

        return style

    # data
    long = long[long["dataset"]==dataset]

    df = long[(long["group"].isin(["ARP", "RD", "DRI", "ER"])) & (long["measure"].isin(MEASURES)) & (long["method"]!= "BM25")]
    df = df.pivot_table(index=["measure", "method"], columns=["dataset", "subcollection", "group"], values="value").sort_index(axis=1)

    # style
    if highlight:
        df_styled = df.style.format(precision=3).format_index(escape="latex")
        for index in df.index.levels[0]:
            for col in df.columns:
                if col[2] in ["ER", "DRI"]:
                    df_styled = df_styled.apply(b_abs, subset=(index, col))
                if col[2] in ["RD", "ARP"]:
                    df_styled = df_styled.apply(b_pos, subset=(index, col))
                if col[2] in ["ER"]:
                    df_styled = df_styled.apply(b_one, subset=(index, col))
        df = df_styled
    if save:
        df.to_latex(f"../../../paper/ECIR23/tables/t-{dataset}.tex", convert_css=True)
    return df

# %%
table_RD_DRI(long, dataset="longeval", highlight=True, save=False)
# Out:
# <style type="text/css">
# #T_d6783_row0_col0, #T_d6783_row0_col1, #T_d6783_row0_col8, #T_d6783_row1_col3, #T_d6783_row1_col5, #T_d6783_row1_col7, #T_d6783_row2_col4, #T_d6783_row4_col4, #T_d6783_row4_col8, #T_d6783_row5_col0, #T_d6783_row5_col7, #T_d6783_row6_col3, #T_d6783_row6_col5, #T_d6783_row7_col1, #T_d6783_row8_col0, #T_d6783_row8_col4, #T_d6783_row8_col8, #T_d6783_row9_col1, #T_d6783_row9_col3, #T_d6783_row9_col5, #T_d6783_row9_col7 {
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_d6783_row0_col2, #T_d6783_row0_col6, #T_d6783_row7_col2, #T_d6783_row8_col2 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_d6783_row0_col3, #T_d6783_row1_col0, #T_d6783_row1_col4, #T_d6783_row1_col8, #T_d6783_row2_col7, #T_d6783_row3_col0, #T_d6783_row5_col4, #T_d6783_row5_col8, #T_d6783_row6_col1, #T_d6783_row6_col7, #T_d6783_row7_col0, #T_d6783_row7_col3, #T_d6783_row8_col7, #T_d6783_row9_col4, #T_d6783_row9_col8, #T_d6783_row11_col0, #T_d6783_row11_col3 {
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row0_col4 {
#   background-color: #d9f0d3;
#   color: black;
# }
# #T_d6783_row0_col5 {
#   background-color: #66bd6f;
#   color: black;
# }
# #T_d6783_row0_col7 {
#   background-color: #aadda4;
#   color: black;
# }
# #T_d6783_row1_col1 {
#   background-color: #127c39;
#   color: white;
# }
# #T_d6783_row1_col2 {
#   background-color: #107a37;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row1_col6 {
#   background-color: #5eb96b;
#   color: black;
#   background-color: #006328;
#   color: white;
# }
# #T_d6783_row2_col0 {
#   background-color: #73c476;
#   color: white;
# }
# #T_d6783_row2_col1 {
#   background-color: #68be70;
#   color: black;
# }
# #T_d6783_row2_col2 {
#   background-color: #2e964d;
#   color: white;
#   background-color: #03702e;
#   color: white;
# }
# #T_d6783_row2_col3 {
#   background-color: #6abf71;
#   color: white;
# }
# #T_d6783_row2_col5 {
#   background-color: #39a257;
#   color: white;
# }
# #T_d6783_row2_col6 {
#   background-color: #006729;
#   color: white;
#   background-color: #006d2c;
#   color: white;
# }
# #T_d6783_row2_col8 {
#   background-color: #a4da9e;
#   color: black;
# }
# #T_d6783_row3_col1 {
#   background-color: #005924;
#   color: white;
# }
# #T_d6783_row3_col2 {
#   background-color: #17813d;
#   color: white;
#   background-color: #004e1f;
#   color: white;
# }
# #T_d6783_row3_col3 {
#   background-color: #d5efcf;
#   color: black;
# }
# #T_d6783_row3_col4 {
#   background-color: #1f8742;
#   color: white;
# }
# #T_d6783_row3_col5 {
#   background-color: #9fd899;
#   color: black;
# }
# #T_d6783_row3_col6 {
#   background-color: #46ae60;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row3_col7, #T_d6783_row5_col3 {
#   background-color: #c1e6ba;
#   color: black;
# }
# #T_d6783_row3_col8 {
#   background-color: #107a37;
#   color: white;
# }
# #T_d6783_row4_col0 {
#   background-color: #f2faf0;
#   color: black;
# }
# #T_d6783_row4_col1 {
#   background-color: #17813d;
#   color: white;
# }
# #T_d6783_row4_col2 {
#   background-color: #98d594;
#   color: black;
#   background-color: #46ae60;
#   color: white;
# }
# #T_d6783_row4_col3 {
#   background-color: #d2edcc;
#   color: black;
# }
# #T_d6783_row4_col5 {
#   background-color: #2c944c;
#   color: white;
# }
# #T_d6783_row4_col6 {
#   background-color: #76c578;
#   color: black;
#   background-color: #9cd797;
#   color: black;
# }
# #T_d6783_row4_col7 {
#   background-color: #53b466;
#   color: white;
# }
# #T_d6783_row5_col1 {
#   background-color: #4eb264;
#   color: black;
# }
# #T_d6783_row5_col2 {
#   background-color: #0e7936;
#   color: white;
#   background-color: #208843;
#   color: white;
# }
# #T_d6783_row5_col5, #T_d6783_row10_col4 {
#   background-color: #bce4b5;
#   color: black;
# }
# #T_d6783_row5_col6 {
#   background-color: #ecf8e8;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row6_col0 {
#   background-color: #b5e1ae;
#   color: black;
# }
# #T_d6783_row6_col2 {
#   background-color: #39a257;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row6_col4 {
#   background-color: #b6e2af;
#   color: black;
# }
# #T_d6783_row6_col6 {
#   background-color: #5db96b;
#   color: black;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_d6783_row6_col8 {
#   background-color: #006b2b;
#   color: white;
# }
# #T_d6783_row7_col4 {
#   background-color: #55b567;
#   color: white;
# }
# #T_d6783_row7_col5 {
#   background-color: #9bd696;
#   color: black;
# }
# #T_d6783_row7_col6 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #75c477;
#   color: black;
# }
# #T_d6783_row7_col7 {
#   background-color: #f1faee;
#   color: black;
# }
# #T_d6783_row7_col8 {
#   background-color: #94d390;
#   color: white;
# }
# #T_d6783_row8_col1 {
#   background-color: #80ca80;
#   color: black;
# }
# #T_d6783_row8_col3 {
#   background-color: #a7dba0;
#   color: black;
# }
# #T_d6783_row8_col5 {
#   background-color: #aedea7;
#   color: black;
# }
# #T_d6783_row8_col6 {
#   background-color: #2c944c;
#   color: white;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_d6783_row9_col0 {
#   background-color: #87cd86;
#   color: white;
# }
# #T_d6783_row9_col2 {
#   background-color: #006529;
#   color: white;
#   background-color: #d5efcf;
#   color: black;
# }
# #T_d6783_row9_col6 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #006428;
#   color: white;
# }
# #T_d6783_row10_col0 {
#   background-color: #50b264;
#   color: white;
# }
# #T_d6783_row10_col1 {
#   background-color: #006529;
#   color: white;
# }
# #T_d6783_row10_col2 {
#   background-color: #5ab769;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row10_col3 {
#   background-color: #228a44;
#   color: white;
# }
# #T_d6783_row10_col5 {
#   background-color: #026f2e;
#   color: white;
# }
# #T_d6783_row10_col6 {
#   background-color: #d5efcf;
#   color: black;
#   background-color: #005924;
#   color: white;
# }
# #T_d6783_row10_col7 {
#   background-color: #339c52;
#   color: white;
# }
# #T_d6783_row10_col8 {
#   background-color: #c4e8bd;
#   color: black;
# }
# #T_d6783_row11_col1 {
#   background-color: #137d39;
#   color: white;
# }
# #T_d6783_row11_col2 {
#   background-color: #bae3b3;
#   color: black;
#   background-color: #2c944c;
#   color: white;
# }
# #T_d6783_row11_col4 {
#   background-color: #81ca81;
#   color: white;
# }
# #T_d6783_row11_col5 {
#   background-color: #005a24;
#   color: white;
# }
# #T_d6783_row11_col6 {
#   background-color: #ddf2d8;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_d6783_row11_col7 {
#   background-color: #3fa85b;
#   color: white;
# }
# #T_d6783_row11_col8 {
#   background-color: #7cc87c;
#   color: white;
# }
# </style>
# <table id="T_d6783">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_d6783_level0_col0" class="col_heading level0 col0" colspan="9">longeval</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >subcollection</th>
#       <th id="T_d6783_level1_col0" class="col_heading level1 col0" colspan="4">LT</th>
#       <th id="T_d6783_level1_col4" class="col_heading level1 col4" colspan="4">ST</th>
#       <th id="T_d6783_level1_col8" class="col_heading level1 col8" >WT</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >group</th>
#       <th id="T_d6783_level2_col0" class="col_heading level2 col0" >ARP</th>
#       <th id="T_d6783_level2_col1" class="col_heading level2 col1" >DRI</th>
#       <th id="T_d6783_level2_col2" class="col_heading level2 col2" >ER</th>
#       <th id="T_d6783_level2_col3" class="col_heading level2 col3" >RD</th>
#       <th id="T_d6783_level2_col4" class="col_heading level2 col4" >ARP</th>
#       <th id="T_d6783_level2_col5" class="col_heading level2 col5" >DRI</th>
#       <th id="T_d6783_level2_col6" class="col_heading level2 col6" >ER</th>
#       <th id="T_d6783_level2_col7" class="col_heading level2 col7" >RD</th>
#       <th id="T_d6783_level2_col8" class="col_heading level2 col8" >ARP</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >measure</th>
#       <th class="index_name level1" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th

# %%
table_RD_DRI(long, dataset="tripclick-test-head", highlight=True, save=False)
# Out:
# <style type="text/css">
# #T_c1819_row0_col0, #T_c1819_row0_col1, #T_c1819_row0_col5, #T_c1819_row3_col4, #T_c1819_row3_col8, #T_c1819_row4_col0, #T_c1819_row4_col1, #T_c1819_row4_col5, #T_c1819_row5_col4, #T_c1819_row7_col8, #T_c1819_row9_col6, #T_c1819_row11_col0, #T_c1819_row11_col1, #T_c1819_row11_col4, #T_c1819_row11_col5, #T_c1819_row11_col8 {
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row0_col2, #T_c1819_row1_col2 {
#   background-color: #84cc83;
#   color: black;
# }
# #T_c1819_row0_col3 {
#   background-color: #e5f5e1;
#   color: black;
#   background-color: #228a44;
#   color: white;
# }
# #T_c1819_row0_col4, #T_c1819_row1_col1 {
#   background-color: #7fc97f;
#   color: white;
# }
# #T_c1819_row0_col6 {
#   background-color: #b0dfaa;
#   color: black;
# }
# #T_c1819_row0_col7 {
#   background-color: #e4f5df;
#   color: black;
#   background-color: #56b567;
#   color: white;
# }
# #T_c1819_row0_col8 {
#   background-color: #98d594;
#   color: black;
# }
# #T_c1819_row1_col0 {
#   background-color: #84cc83;
#   color: white;
# }
# #T_c1819_row1_col3 {
#   background-color: #d5efcf;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row1_col4 {
#   background-color: #8ed08b;
#   color: white;
# }
# #T_c1819_row1_col5 {
#   background-color: #b4e1ad;
#   color: black;
# }
# #T_c1819_row1_col6, #T_c1819_row1_col8, #T_c1819_row2_col0, #T_c1819_row2_col1, #T_c1819_row2_col2, #T_c1819_row2_col4, #T_c1819_row2_col5, #T_c1819_row4_col6, #T_c1819_row4_col8, #T_c1819_row6_col0, #T_c1819_row6_col1, #T_c1819_row6_col2, #T_c1819_row6_col4, #T_c1819_row6_col5, #T_c1819_row8_col2, #T_c1819_row8_col4, #T_c1819_row8_col6, #T_c1819_row8_col8, #T_c1819_row10_col0, #T_c1819_row10_col1, #T_c1819_row10_col5 {
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c1819_row1_col7 {
#   background-color: #99d595;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row2_col3 {
#   background-color: #349d53;
#   color: white;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c1819_row2_col6, #T_c1819_row7_col6 {
#   background-color: #6bc072;
#   color: black;
# }
# #T_c1819_row2_col7 {
#   background-color: #91d28e;
#   color: black;
#   background-color: #006428;
#   color: white;
# }
# #T_c1819_row2_col8 {
#   background-color: #62bb6d;
#   color: white;
# }
# #T_c1819_row3_col0 {
#   background-color: #3fa85b;
#   color: white;
# }
# #T_c1819_row3_col1 {
#   background-color: #006b2b;
#   color: white;
# }
# #T_c1819_row3_col2, #T_c1819_row3_col5 {
#   background-color: #006c2c;
#   color: white;
# }
# #T_c1819_row3_col3 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #b5e1ae;
#   color: black;
# }
# #T_c1819_row3_col6 {
#   background-color: #016e2d;
#   color: white;
# }
# #T_c1819_row3_col7, #T_c1819_row6_col3, #T_c1819_row6_col7, #T_c1819_row11_col7 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c1819_row4_col2 {
#   background-color: #107a37;
#   color: white;
# }
# #T_c1819_row4_col3, #T_c1819_row5_col3, #T_c1819_row7_col3, #T_c1819_row7_col7 {
#   background-color: #00441b;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row4_col4 {
#   background-color: #5eb96b;
#   color: white;
# }
# #T_c1819_row4_col7, #T_c1819_row5_col7 {
#   background-color: #00451c;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row5_col0, #T_c1819_row7_col0 {
#   background-color: #3da65a;
#   color: white;
# }
# #T_c1819_row5_col1 {
#   background-color: #90d18d;
#   color: white;
# }
# #T_c1819_row5_col2 {
#   background-color: #95d391;
#   color: black;
# }
# #T_c1819_row5_col5 {
#   background-color: #4bb062;
#   color: white;
# }
# #T_c1819_row5_col6, #T_c1819_row9_col1 {
#   background-color: #a9dca3;
#   color: black;
# }
# #T_c1819_row5_col8 {
#   background-color: #40aa5d;
#   color: white;
# }
# #T_c1819_row6_col6 {
#   background-color: #e4f5df;
#   color: black;
# }
# #T_c1819_row6_col8 {
#   background-color: #e5f5e0;
#   color: black;
# }
# #T_c1819_row7_col1 {
#   background-color: #48ae60;
#   color: white;
# }
# #T_c1819_row7_col2 {
#   background-color: #1d8640;
#   color: white;
# }
# #T_c1819_row7_col4 {
#   background-color: #7ac77b;
#   color: white;
# }
# #T_c1819_row7_col5 {
#   background-color: #63bc6e;
#   color: white;
# }
# #T_c1819_row8_col0, #T_c1819_row9_col8 {
#   background-color: #2a924a;
#   color: white;
# }
# #T_c1819_row8_col1, #T_c1819_row8_col5 {
#   background-color: #7cc87c;
#   color: white;
# }
# #T_c1819_row8_col3 {
#   background-color: #aadda4;
#   color: black;
#   background-color: #99d595;
#   color: black;
# }
# #T_c1819_row8_col7 {
#   background-color: #b4e1ad;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row9_col0 {
#   background-color: #aedea7;
#   color: black;
# }
# #T_c1819_row9_col2 {
#   background-color: #258d47;
#   color: white;
# }
# #T_c1819_row9_col3 {
#   background-color: #e3f4de;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c1819_row9_col4 {
#   background-color: #19833e;
#   color: white;
# }
# #T_c1819_row9_col5 {
#   background-color: #a5db9f;
#   color: black;
# }
# #T_c1819_row9_col7 {
#   background-color: #ecf8e8;
#   color: black;
#   background-color: #4eb264;
#   color: white;
# }
# #T_c1819_row10_col2 {
#   background-color: #3ba458;
#   color: white;
# }
# #T_c1819_row10_col3 {
#   background-color: #79c67a;
#   color: black;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c1819_row10_col4 {
#   background-color: #2f984f;
#   color: white;
# }
# #T_c1819_row10_col6 {
#   background-color: #1f8742;
#   color: white;
# }
# #T_c1819_row10_col7 {
#   background-color: #b0dfaa;
#   color: black;
#   background-color: #006328;
#   color: white;
# }
# #T_c1819_row10_col8 {
#   background-color: #6bc072;
#   color: white;
# }
# #T_c1819_row11_col2 {
#   background-color: #006027;
#   color: white;
# }
# #T_c1819_row11_col3 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #289049;
#   color: white;
# }
# #T_c1819_row11_col6 {
#   background-color: #3ca559;
#   color: white;
# }
# </style>
# <table id="T_c1819">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_c1819_level0_col0" class="col_heading level0 col0" colspan="9">tripclick-test-head</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >subcollection</th>
#       <th id="T_c1819_level1_col0" class="col_heading level1 col0" >t1</th>
#       <th id="T_c1819_level1_col1" class="col_heading level1 col1" colspan="4">t2</th>
#       <th id="T_c1819_level1_col5" class="col_heading level1 col5" colspan="4">t3</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >group</th>
#       <th id="T_c1819_level2_col0" class="col_heading level2 col0" >ARP</th>
#       <th id="T_c1819_level2_col1" class="col_heading level2 col1" >ARP</th>
#       <th id="T_c1819_level2_col2" class="col_heading level2 col2" >DRI</th>
#       <th id="T_c1819_level2_col3" class="col_heading level2 col3" >ER</th>
#       <th id="T_c1819_level2_col4" class="col_heading level2 col4" >RD</th>
#       <th id="T_c1819_level2_col5" class="col_heading level2 col5" >ARP</th>
#       <th id="T_c1819_level2_col6" class="col_heading level2 col6" >DRI</th>
#       <th id="T_c1819_level2_col7" class="col_heading level2 col7" >ER</th>
#       <th id="T_c1819_level2_col8" class="col_heading level2 col8" >RD</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >measure</th>
#       <th class="index_name level1" >method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1819_level0_row0" class="row_heading level0 row0" rowspan="4">P\_10</th>
#       <th id="T_c1819_level1_row0" class="row_heading level1 row0" >ColBERT</th>
#       <td id="T_c1819_row0_col0" class="data row0 col0" >0.096</td>
#       <td id="T_c1819_row0_col1" class="data row0 col1" >0.130</td>
#       <td i

# %%
table_RD_DRI(long, dataset="trec-covid", highlight=True, save=False)
# Out:
# <style type="text/css">
# #T_c9e71_row0_col0, #T_c9e71_row0_col2, #T_c9e71_row0_col4, #T_c9e71_row0_col5, #T_c9e71_row0_col9, #T_c9e71_row0_col10, #T_c9e71_row0_col13, #T_c9e71_row1_col14, #T_c9e71_row2_col1, #T_c9e71_row2_col12, #T_c9e71_row2_col16, #T_c9e71_row3_col0, #T_c9e71_row3_col2, #T_c9e71_row3_col4, #T_c9e71_row3_col6, #T_c9e71_row3_col8, #T_c9e71_row4_col0, #T_c9e71_row4_col1, #T_c9e71_row4_col2, #T_c9e71_row4_col5, #T_c9e71_row4_col9, #T_c9e71_row4_col13, #T_c9e71_row5_col6, #T_c9e71_row5_col10, #T_c9e71_row5_col12, #T_c9e71_row5_col14, #T_c9e71_row6_col4, #T_c9e71_row6_col16, #T_c9e71_row7_col8, #T_c9e71_row8_col0, #T_c9e71_row8_col1, #T_c9e71_row8_col4, #T_c9e71_row8_col5, #T_c9e71_row8_col6, #T_c9e71_row8_col8, #T_c9e71_row8_col9, #T_c9e71_row8_col13, #T_c9e71_row8_col14, #T_c9e71_row8_col16, #T_c9e71_row10_col12, #T_c9e71_row11_col2, #T_c9e71_row11_col10 {
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c9e71_row0_col1, #T_c9e71_row3_col1 {
#   background-color: #aedea7;
#   color: black;
# }
# #T_c9e71_row0_col3, #T_c9e71_row1_col7, #T_c9e71_row3_col3, #T_c9e71_row7_col7, #T_c9e71_row10_col15, #T_c9e71_row11_col7 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row0_col6, #T_c9e71_row10_col1 {
#   background-color: #005f26;
#   color: white;
# }
# #T_c9e71_row0_col7 {
#   background-color: #d7efd1;
#   color: black;
#   background-color: #1a843f;
#   color: white;
# }
# #T_c9e71_row0_col8, #T_c9e71_row3_col12, #T_c9e71_row7_col6 {
#   background-color: #16803c;
#   color: white;
# }
# #T_c9e71_row0_col11, #T_c9e71_row0_col15, #T_c9e71_row4_col15, #T_c9e71_row6_col3 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c9e71_row0_col12, #T_c9e71_row1_col0, #T_c9e71_row1_col1, #T_c9e71_row1_col5, #T_c9e71_row1_col16, #T_c9e71_row2_col4, #T_c9e71_row2_col8, #T_c9e71_row2_col9, #T_c9e71_row2_col13, #T_c9e71_row4_col4, #T_c9e71_row5_col0, #T_c9e71_row5_col1, #T_c9e71_row5_col8, #T_c9e71_row5_col9, #T_c9e71_row5_col16, #T_c9e71_row6_col12, #T_c9e71_row6_col14, #T_c9e71_row7_col5, #T_c9e71_row7_col13, #T_c9e71_row9_col0, #T_c9e71_row9_col1, #T_c9e71_row10_col0, #T_c9e71_row10_col4, #T_c9e71_row10_col8, #T_c9e71_row10_col9, #T_c9e71_row10_col13, #T_c9e71_row11_col5, #T_c9e71_row11_col12, #T_c9e71_row11_col16 {
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row0_col14, #T_c9e71_row6_col0 {
#   background-color: #caeac3;
#   color: black;
# }
# #T_c9e71_row0_col16 {
#   background-color: #006729;
#   color: white;
# }
# #T_c9e71_row1_col2 {
#   background-color: #a9dca3;
#   color: black;
# }
# #T_c9e71_row1_col3 {
#   background-color: #d6efd0;
#   color: black;
#   background-color: #5bb86a;
#   color: white;
# }
# #T_c9e71_row1_col4 {
#   background-color: #72c375;
#   color: white;
# }
# #T_c9e71_row1_col6 {
#   background-color: #76c578;
#   color: black;
# }
# #T_c9e71_row1_col8 {
#   background-color: #90d18d;
#   color: white;
# }
# #T_c9e71_row1_col9 {
#   background-color: #3fa85b;
#   color: white;
# }
# #T_c9e71_row1_col10 {
#   background-color: #abdda5;
#   color: black;
# }
# #T_c9e71_row1_col11 {
#   background-color: #005f26;
#   color: white;
#   background-color: #238b45;
#   color: white;
# }
# #T_c9e71_row1_col12 {
#   background-color: #4bb062;
#   color: white;
# }
# #T_c9e71_row1_col13 {
#   background-color: #b8e3b2;
#   color: black;
# }
# #T_c9e71_row1_col15 {
#   background-color: #2d954d;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row2_col0 {
#   background-color: #4aaf61;
#   color: white;
# }
# #T_c9e71_row2_col2 {
#   background-color: #00682a;
#   color: white;
# }
# #T_c9e71_row2_col3 {
#   background-color: #8ed08b;
#   color: black;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c9e71_row2_col5 {
#   background-color: #b2e0ac;
#   color: black;
# }
# #T_c9e71_row2_col6 {
#   background-color: #4bb062;
#   color: black;
# }
# #T_c9e71_row2_col7 {
#   background-color: #0a7633;
#   color: white;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c9e71_row2_col10 {
#   background-color: #016e2d;
#   color: white;
# }
# #T_c9e71_row2_col11 {
#   background-color: #278f48;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row2_col14 {
#   background-color: #004e1f;
#   color: white;
# }
# #T_c9e71_row2_col15 {
#   background-color: #05712f;
#   color: white;
#   background-color: #1f8742;
#   color: white;
# }
# #T_c9e71_row3_col5 {
#   background-color: #7dc87e;
#   color: white;
# }
# #T_c9e71_row3_col7 {
#   background-color: #aadda4;
#   color: black;
#   background-color: #52b365;
#   color: white;
# }
# #T_c9e71_row3_col9, #T_c9e71_row7_col12 {
#   background-color: #e0f3db;
#   color: black;
# }
# #T_c9e71_row3_col10 {
#   background-color: #ccebc6;
#   color: black;
# }
# #T_c9e71_row3_col11 {
#   background-color: #d5efcf;
#   color: black;
#   background-color: #c3e7bc;
#   color: black;
# }
# #T_c9e71_row3_col13 {
#   background-color: #acdea6;
#   color: black;
# }
# #T_c9e71_row3_col14 {
#   background-color: #4db163;
#   color: black;
# }
# #T_c9e71_row3_col15 {
#   background-color: #9fd899;
#   color: black;
#   background-color: #46ae60;
#   color: white;
# }
# #T_c9e71_row3_col16 {
#   background-color: #81ca81;
#   color: white;
# }
# #T_c9e71_row4_col3 {
#   background-color: #dbf1d6;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row4_col6, #T_c9e71_row6_col6 {
#   background-color: #218944;
#   color: white;
# }
# #T_c9e71_row4_col7 {
#   background-color: #3aa357;
#   color: white;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c9e71_row4_col8, #T_c9e71_row6_col8 {
#   background-color: #eff9eb;
#   color: black;
# }
# #T_c9e71_row4_col10 {
#   background-color: #48ae60;
#   color: white;
# }
# #T_c9e71_row4_col11 {
#   background-color: #f7fcf5;
#   color: black;
#   background-color: #3fa95c;
#   color: white;
# }
# #T_c9e71_row4_col12, #T_c9e71_row7_col1 {
#   background-color: #37a055;
#   color: white;
# }
# #T_c9e71_row4_col14 {
#   background-color: #66bd6f;
#   color: black;
# }
# #T_c9e71_row4_col16 {
#   background-color: #76c578;
#   color: white;
# }
# #T_c9e71_row5_col2, #T_c9e71_row7_col14, #T_c9e71_row9_col16 {
#   background-color: #006227;
#   color: white;
# }
# #T_c9e71_row5_col3 {
#   background-color: #a5db9f;
#   color: black;
#   background-color: #6abf71;
#   color: white;
# }
# #T_c9e71_row5_col4 {
#   background-color: #80ca80;
#   color: white;
# }
# #T_c9e71_row5_col5 {
#   background-color: #006b2b;
#   color: white;
# }
# #T_c9e71_row5_col7 {
#   background-color: #81ca81;
#   color: black;
#   background-color: #bae3b3;
#   color: black;
# }
# #T_c9e71_row5_col11 {
#   background-color: #289049;
#   color: white;
#   background-color: #a8dca2;
#   color: black;
# }
# #T_c9e71_row5_col13 {
#   background-color: #75c477;
#   color: white;
# }
# #T_c9e71_row5_col15 {
#   background-color: #005020;
#   color: white;
#   background-color: #80ca80;
#   color: black;
# }
# #T_c9e71_row6_col1 {
#   background-color: #58b668;
#   color: white;
# }
# #T_c9e71_row6_col2 {
#   background-color: #a4da9e;
#   color: black;
# }
# #T_c9e71_row6_col5 {
#   background-color: #a8dca2;
#   color: black;
# }
# #T_c9e71_row6_col7 {
#   background-color: #afdfa8;
#   color: black;
#   background-color: #75c477;
#   color: black;
# }
# #T_c9e71_row6_col9 {
#   background-color: #1f8742;
#   color: white;
# }
# #T_c9e71_row6_col10 {
#   background-color: #006d2c;
#   color: white;
# }
# #T_c9e71_row6_col11 {
#   background-color: #8bcf89;
#   color: black;
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row6_col13 {
#   background-color: #278f48;
#   color: white;
# }
# #T_c9e71_row6_col15 {
#   background-color: #3ba458;
#   color: white;
#   background-color: #00441b;
#   color: white;
# }
# #T_c9e71_row7_col0, #T_c9e71_row11_col8 {
#   background-color: #43ac5e;
#   color: white;
# }
# #T_c9e71_row7_col2 {
#   background-color: #107a37;
#   color: white;
# }
# #T_c9e71_row7_col3 {
#   background-color: #9bd696;
#   color: black;
#   background-color: #afdfa8;
#   color: black;
# }
# #T_c9e71_row7_col4 {
#   background-color: #73c476;
#   color: white;
# }
# #T_c9e71_row7_col9 {
#   background-color: #7fc97f;
#   color: white;
# }
# #T_c9e71_row7_col10 {
#   background-color: #e1f3dc;
#   color: black;
# }
# #T_c9e71_row7_col11 {
#   background-color: #006729;
#   color: white;
#   background-color: #f7fcf5;
#   color: black;
# }
# #T_c9e71_row7_col15 {
#   back

# %% [markdown]
# # ARP

# %%
# Plot
plt.rcParams.update({'font.size': 13})
figure, axis = plt.subplots(1, 3, figsize=(15,5))

measure = "bpref"
symbols=["-P","-o","-v","-s", "-d"]
DISPLAY_NAMES = {
    'bm25': "BM25",
    "E5": "E5",
    'bm25+colbert': "ColBERT", 
    'rrf(xsqram__bm25_bo1__pl2)': "RRF", 
    'bm25+monot5': "MonoT5",
    'bm25_d2q10': "d2q",
}

# Data
dataset = "longeval"
title = "LongEval"

res = df[df["dataset"]==dataset]
sorted_columns = ["WT", "ST", "LT"]

res = res.pivot_table(index='method', columns='subcollection', values=f"ARP_{measure}")[sorted_columns].T

for i, sym in enumerate(symbols):
    axis[0].plot(res.index, res[res.columns[i]], sym, alpha=0.7)
axis[0].set_ylabel("bpref")
axis[0].set_title(title)




dataset = "tripclick-test-head"
title = "TripClick"

res = df[df["dataset"]==dataset]

res = res.pivot_table(index='method', columns='subcollection', values=f"ARP_{measure}").T

for i, sym in enumerate(symbols):
    axis[1].plot(res.index, res[res.columns[i]], sym, alpha=0.7)
axis[1].set_title(title)



dataset = "trec-covid"
title = "Trec-Covid"

res = df[df["dataset"]==dataset]

res = res.pivot_table(index='method', columns='subcollection', values=f"ARP_{measure}").T

for i, sym in enumerate(symbols):
    axis[2].plot(res.index, res[res.columns[i]], sym, alpha=0.7)
axis[2].set_title(title)


figure.subplots_adjust(bottom=0.3, wspace=0.33)

display_name = [DISPLAY_NAMES[m] for m in res.columns]
axis[2].legend(display_name, loc='upper center', bbox_to_anchor=(0.-0.8, -0.15), ncol=6)
# figure.suptitle(title)

plt.savefig(f"../../../paper/ECIR23/figures/ARP_all.png", bbox_inches='tight', dpi=700)

# %%
plot_arp(df, "tripclick-test-head", title="TripClick")
plot_arp(df, "longeval", title="LongEval", sorted_columns=["WT", "ST", "LT"])
plot_arp(df, "trec-covid", title="Trec-Covid", legend=True)

# %% [markdown]
# # Diff

# %%
plot_per_topic_dif(df, "trec-covid", "bm25", "ndcg", subcollections = ["round1", "round2", "round3", "round4", "round5"])
plot_per_topic_dif(df, "tripclick-test-head", "bm25", "ndcg", subcollections=["t1", "t2", "t3"], cut_off=30)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Per topic

# %%
plot_per_topic(df, "trec-covid", "bm25", "ndcg", subcollections=["round1", "round2", "round3", "round4", "round5"], cut_off=30)
plot_per_topic(df, "tripclick-test-head", "bm25", "ndcg", subcollections=["t1", "t2", "t3"], cut_off=30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plot_per_topic(df, "trec-covid", "bm25", "ndcg", subcollections=["round1", "round2", "round3", "round4", "round5"], cut_off=30)
#       2 plot_per_topic(df, "tripclick-test-head", "bm25", "ndcg", subcollections=["t1", "t2", "t3"], cut_off=30)
#
# File ~/dev/DCIR/evaluation/plot.py:65, in plot_per_topic(df, dataset, method, measure, subcollections, cut_off, save)
#      62     per_topic = df[(df["dataset"]==dataset) & (df["subcollection"]==subcollection) & (df["method"]==method)].iloc[0]["arp_per_topic"]
#      64     for topic in per_topic.keys():
# ---> 65         data[topic][subcollection] = per_topic[topic][f"ARP_{measure}"]
#      67 data = pd.DataFrame(data).T.head(cut_off)
#      69 # Plot
#
# KeyError: 'ARP_ndcg'

# %% [markdown]
# # Delta

# %%
plot_per_topic_delta(df, "trec-covid", "bm25", "ndcg", subcollections = ["round1", "round2"], cut_off=30)
plot_per_topic_delta(df, "tripclick-test-head", "bm25", "ndcg", subcollections=["t1", "t2"], cut_off=200)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[338], line 1
# ----> 1 plot_per_topic_delta(df, "trec-covid", "bm25", "ndcg", subcollections = ["round1", "round2"], cut_off=30)
#       2 plot_per_topic_delta(df, "tripclick-test-head", "bm25", "ndcg", subcollections=["t1", "t2"], cut_off=200)
#
# File ~/dev/DCIR/evaluation/plot.py:115, in plot_per_topic_delta(df, dataset, method, measure, subcollections, cut_off, save)
#     112     per_topic = df[(df["dataset"]==dataset) & (df["subcollection"]==subcollection) & (df["method"]==method)].iloc[0]["arp_per_topic"]
#     114     for topic in per_topic.keys():
# --> 115         data[topic][subcollection] = per_topic[topic][f"ARP_{measure}"]
#     117 data = pd.DataFrame(data).T.head(cut_off)
#     119 data["delta"] = data[subcollections[0]] - data[subcollections[1]]
#
# KeyError: 'ARP_ndcg'

# %% [markdown]
# # DRI

# %%
long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="ER")&(long["subcollection"]==subcollection)]#["value"].clip(0,2)
# Out:
# Empty DataFrame
# Columns: [method, subcollection, dataset, variable, value, group, measure]
# Index: []

# %%
long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="ER")&(long["subcollection"]==subcollection)]["value"].clip(0,2)
# Out:
# 14796    0.663
# 14803    0.584
# 14808    1.213
# 14813    1.315
# 14829      NaN
# Name: value, dtype: object

# %%
long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="ER")&(long["subcollection"]==subcollection)]["value"].clip(0,2)

# %%
from adjustText import adjust_text

# %%
long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="ER")&(long["subcollection"]==subcollection)&(long["method"]==method)]
# Out:
#         method subcollection   dataset  variable  value group measure
# 14796  ColBERT            ST  longeval  ER_bpref  0.663    ER   bpref

# %%
subcollections = ["ST", "LT"]
dataset = "longeval"
measures = ["bpref"]
marker_color = [('o', "#1f78b4"), ('^', '#33a02c'), ('v', '#e31a1b')]
fig, ax = plt.subplots(figsize=(7, 7))
methods = long["method"].unique()

texts = []
for measure, mk in zip(measures, marker_color[:1]):
    for method in methods[1:]:  # we have 4 systems
            x = []
            y = []
            name = []
            for subcollection in subcollections:
                # data
                d = long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="ER")&(long["subcollection"]==subcollection)&(long["method"]==method)]["value"].clip(0,2)
                x.append(d.values)

                d = long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="DRI")&(long["subcollection"]==subcollection)&(long["method"]==method)]["value"].clip(-0.1,0.1)
                y.append(d.values)
                
                # label
                name.append(method + " " + subcollection)


            # plot data        
            ax.plot(x, y, marker=mk[0], color=mk[1], linestyle=':', label=measure)

            for x_cord, y_cord, system_name in zip(x, y, name):
                texts.append(ax.text(x_cord, y_cord, system_name, fontsize=12))
                
    # # data
    # er = long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="ER")&(long["subcollection"]==subcollection)]["value"].clip(0,2)
    # dri = long[(long["dataset"] == dataset)&(long["measure"]==measure)&(long["group"]=="DRI")&(long["subcollection"]==subcollection)]["value"].clip(-0.1,0.1)

    # plot
    # ax.plot(er,dri, marker=mk[0], color=mk[1], linestyle='None', label=measure)

    # label
    # plot label



# style
ax.tick_params(axis='y', labelcolor='k')
ax.axhline(0, color='grey')  
ax.axvline(1, color='grey')

ax.grid(False)  # disable grid
ax.set_xlabel('Effect Ratio (ER)')
ax.set_ylabel(u'Delta Relative Improvement ($\Delta$RI)')


ax.set_ylim(-0.1,0.1)
ax.set_xlim(0,2)

ax.legend(loc='lower left')
ax.set_title(f'{dataset} {subcollection}\n')
_ = adjust_text(texts, ax=ax)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 59
#      57 ax.legend(loc='lower left')
#      58 ax.set_title(f'{dataset} {subcollection}\n')
# ---> 59 _ = adjust_text(texts, ax=ax)
#      61 plt.show()
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/adjustText/__init__.py:573, in adjust_text(texts, x, y, add_objects, ax, expand_text, expand_points, expand_objects, expand_align, autoalign, va, ha, force_text, force_points, force_objects, lim, precision, only_move, avoid_text, avoid_points, avoid_self, save_steps, save_prefix, save_format, add_step_numbers, *args, **kwargs)
#     571         x[ix] = t_x
#     572         y[ix] = t_y
# --> 573 orig_xy = [get_text_position(text, ax) for text in texts]
#     574 orig_x = [xy[0] for xy in orig_xy]
#     575 orig_y = [xy[1] for xy in orig_xy]
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/adjustText/__init__.py:573, in <listcomp>(.0)
#     571         x[ix] = t_x
#     572         y[ix] = t_y
# --> 573 orig_xy = [get_text_position(text, ax) for text in texts]
#     574 orig_x = [xy[0] for xy in orig_xy]
#     575 orig_y = [xy[1] for xy in orig_xy]
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/adjustText/__init__.py:57, in get_text_position(text, ax)
#      55 x = ax.convert_xunits(x)
#      56 y = ax.convert_yunits(y)
# ---> 57 t_x, t_y = text.get_transform().transform((x, y))
#      58 return (t_x, t_y)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/matplotlib/transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/matplotlib/transforms.py:2415, in CompositeGenericTransform.transform_affine(self, points)
#    2413 def transform_affine(self, points):
#    2414     # docstring inherited
# -> 2415     return self.get_affine().transform(points)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/matplotlib/transforms.py:1779, in AffineBase.transform(self, values)
#    1777 def transform(self, values):
#    1778     # docstring inherited
# -> 1779     return self.transform_affine(values)
#
# File ~/miniconda3/envs/LongEval/lib/python3.8/site-packages/matplotlib/transforms.py:1848, in Affine2DBase.transform_affine(self, points)
#    1846     tpoints = affine_transform(points.data, mtx)
#    1847     return np.ma.MaskedArray(tpoints, mask=np.ma.getmask(points))
# -> 1848 return affine_transform(points, mtx)
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'

# %%
plt.rcParams.update({'font.size': 16})
def plot_ER_DRI_multi(subcollections, methods=["bm25+colbert"], measures = ['P_10', 'bpref', 'ndcg']):
# subcollections = ["ST", "LT"]
# methods=["bm25+monot5", "bm25_d2q10"]
# measures = ['P_10', 'bpref', 'ndcg']

    marker_color = [('o', "#1f78b4"), ('^', '#33a02c'), ('v', '#e31a1b')][:len(measures)]

    fig, ax1 = plt.subplots(figsize=(7, 7))

    # style
    ax1.tick_params(axis='y', labelcolor='k')
    ax1.axhline(0, color='grey')  
    ax1.axvline(1, color='grey')

    ax1.grid(False)  # disable grid
    ax1.set_xlabel('Effect Ratio (ER)')
    ax1.set_ylabel(u'Delta Relative Improvement ($\Delta$RI)')

    dataset = runs_a_rep[runs_a_rep["subcollection"]==subcollections[0]]["dataset"].iloc[0]
    ax1.set_title(f'{dataset} over {" ".join(subcollections)}\n')

    ax1.set_ylim(-0.1,0.1)
    ax1.set_xlim(0,2)

    # Plot
    texts = []
    for measure, mk in zip(measures, marker_color):
        for method in methods:  # we have 4 systems
            x = []
            y = []
            name = []
            for subcollection in subcollections:
                # data
                d = runs_a_rep[runs_a_rep["subcollection"]==subcollection].set_index("method")[f"ER_{measure}"].clip(0,2)
                x.append(d[method])
                d = runs_a_rep[runs_a_rep["subcollection"]==subcollection].set_index("method")[f"DRI_{measure}"].clip(-0.1,0.1)
                y.append(d[method])
                
                # label
                name.append(r_patch[method] + " " + subcollection)

            # plot data        
            ax1.plot(x, y, marker=mk[0], color=mk[1], linestyle=':', label=measure)

            # plot label
            for x_cord, y_cord, system_name in zip(x, y, name):
                texts.append(ax1.text(x_cord, y_cord, system_name,color=mk[1], fontsize=12))
                
        
    _ = adjust_text(texts, ax=ax1)

    plt.savefig(f"../../../paper/ECIR23/figures/ER_DRI_multi_{dataset}-{subcollection}.pdf", bbox_inches='tight')
    plt.show()

# %%
plot_DRI_ER(long)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.rcParams.update({'font.size': 16})
def plot_ER_DRI_multi(subcollections, methods=["bm25+colbert"], measures = ['P_10', 'bpref', 'ndcg']):
# subcollections = ["ST", "LT"]
# methods=["bm25+monot5", "bm25_d2q10"]
# measures = ['P_10', 'bpref', 'ndcg']

    marker_color = [('o', "#1f78b4"), ('^', '#33a02c'), ('v', '#e31a1b')][:len(measures)]

    fig, ax1 = plt.subplots(figsize=(7, 7))

    # style
    ax1.tick_params(axis='y', labelcolor='k')
    ax1.axhline(0, color='grey')  
    ax1.axvline(1, color='grey')

    ax1.grid(False)  # disable grid
    ax1.set_xlabel('Effect Ratio (ER)')
    ax1.set_ylabel(u'Delta Relative Improvement ($\Delta$RI)')

    dataset = runs_a_rep[runs_a_rep["subcollection"]==subcollections[0]]["dataset"].iloc[0]
    ax1.set_title(f'{dataset} over {" ".join(subcollections)}\n')

    ax1.set_ylim(-0.1,0.1)
    ax1.set_xlim(0,2)

    # Plot
    texts = []
    for measure, mk in zip(measures, marker_color):
        for method in methods:  # we have 4 systems
            x = []
            y = []
            name = []
            for subcollection in subcollections:
                # data
                d = runs_a_rep[runs_a_rep["subcollection"]==subcollection].set_index("method")[f"ER_{measure}"].clip(0,2)
                x.append(d[method])
                d = runs_a_rep[runs_a_rep["subcollection"]==subcollection].set_index("method")[f"DRI_{measure}"].clip(-0.1,0.1)
                y.append(d[method])
                
                # label
                name.append(r_patch[method] + " " + subcollection)

            # plot data        
            ax1.plot(x, y, marker=mk[0], color=mk[1], linestyle=':', label=measure)

            # plot label
            for x_cord, y_cord, system_name in zip(x, y, name):
                texts.append(ax1.text(x_cord, y_cord, system_name,color=mk[1], fontsize=12))
                
        
    _ = adjust_text(texts, ax=ax1)

    # plt.savefig(f"../../../paper/ECIR23/figures/ER_DRI_multi_{dataset}-{subcollection}.pdf", bbox_inches='tight')
    plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plot_ER_DRI_multi(methods=["bm25+colbert", "rrf(xsqram__bm25_bo1__pl2)", "bm25+monot5", "bm25_d2q10"], subcollections=["t2", "t3"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plot_ER_DRI_multi(methods=["bm25+colbert", "rrf(xsqram__bm25_bo1__pl2)", "bm25+monot5", "bm25_d2q10"], subcollections=["t2", "t3"])
#
# Cell In[10], line 20, in plot_ER_DRI_multi(subcollections, methods, measures)
#      17 ax1.set_xlabel('Effect Ratio (ER)')
#      18 ax1.set_ylabel(u'Delta Relative Improvement ($\Delta$RI)')
# ---> 20 dataset = runs_a_rep[runs_a_rep["subcollection"]==subcollections[0]]["dataset"].iloc[0]
#      21 ax1.set_title(f'{dataset} over {" ".join(subcollections)}\n')
#      23 ax1.set_ylim(-0.1,0.1)
#
# NameError: name 'runs_a_rep' is not defined

# %% [markdown]
# # RMSE

# %%
table = df

# %%
runs_b_orig = table[
    (table["subcollection"].isin(["WT", "t1", "round1"]))
    & (table["method"] == "bm25")
]
runs_a_orig = table[
    (table["subcollection"].isin(["WT", "t1", "round1"]))
    & (table["method"] != "bm25")
]

runs_b_rep = table[
    (~table["subcollection"].isin(["WT", "t1", "round1"]))
    & (table["method"] == "bm25")
]
runs_a_rep = table[
    (~table["subcollection"].isin(["WT", "t1", "round1"]))
    & (table["method"] != "bm25")
]

# %%
row = table.iloc[1]
row
# Out:
# dataset                    longeval
# subcollection                    ST
# queries                        test
# method                 bm25+colbert
# implementation            pyterrier
#                            ...
# RMSE_set_P                 0.001214
# RMSE_set_relative_P        0.282617
# RMSE_set_recall            0.282617
# RMSE_set_map               0.001523
# RMSE_set_F                  0.00241
# Name: 1, Length: 550, dtype: object

# %%
def get_qrels_name_from_row(row):
    qrels_type = {"tripclick-test-head": "test-head-dctr"}  # tripclick needs mapping

    qrels_name = row.dataset + "-" + row.subcollection + ".qrels"
    if row.queries != "queries":
        qrels_name += "-" + row.queries
    if row.dataset in qrels_type.keys():
        qrels_name += "-" + qrels_type[row.dataset]

    return qrels_name

# %%
from repro_eval.Evaluator import RpdEvaluator, RplEvaluator

# %%
# Original
# get qrel baseline
qrel_orig_path = get_qrels_name_from_row(
    runs_b_orig[runs_b_orig["dataset"] == row["dataset"]].iloc[0]
)
# baseline
run_b_orig_path = runs_b_orig[
    runs_b_orig["dataset"] == row["dataset"]
].iloc[0]["filename"]
# advanced
run_a_orig_path = runs_a_orig[
    (runs_a_orig["dataset"] == row["dataset"])
    & (runs_a_orig["method"] == row["method"])
].iloc[0]["filename"]

# Replicated
# get baseline
run_b_rep_path = runs_b_rep[
    runs_b_rep["subcollection"] == row["subcollection"]
].iloc[0]["filename"]
# get qrel advanced
qrel_rpl_path = get_qrels_name_from_row(row)

# %%
import pytrec_eval
from repro_eval.measure.document_order import ktau_union as ktu, RBO

# %%
mode = "-core_queries"

# %%
qrel_orig_path="../data/qrels/" + qrel_orig_path + mode
run_b_orig_path=f"../data/run{mode}/" + run_b_orig_path
run_a_orig_path=f"../data/run{mode}/" + run_a_orig_path
run_b_rep_path=f"../data/run{mode}/" + run_b_rep_path
run_a_rep_path=f"../data/run{mode}/" + row["filename"]
qrel_rpl_path="../data/qrels/" + qrel_rpl_path + mode

# %%
with open(run_b_rep_path, 'r') as b_run, open(run_a_rep_path, 'r') as a_run:
    run_b_rep = pytrec_eval.parse_run(b_run)
    run_b_rep = {t: run_b_rep[t] for t in sorted(run_b_rep)}
    run_a_rep = pytrec_eval.parse_run(a_run)
    run_a_rep = {t: run_a_rep[t] for t in sorted(run_a_rep)}

# %%
with open(run_b_orig_path, 'r') as b_run, open(run_a_orig_path, 'r') as a_run:
    run_b_orig = pytrec_eval.parse_run(b_run)
    run_b_orig = {t: run_b_orig[t] for t in sorted(run_b_orig)}
    run_a_orig = pytrec_eval.parse_run(a_run)
    run_a_orig = {t: run_a_orig[t] for t in sorted(run_a_orig)}

# %%
run_b_orig_path
# Out:
# '../data/run-core_queries/run-longeval-WT-queries-bm25-pyterrier'

# %%
rpd_eval = RpdEvaluator(
    qrel_orig_path="../data/qrels/" + qrel_orig_path + mode,
    run_b_orig_path=f"../data/run{mode}/" + run_b_orig_path,
    run_a_orig_path=f"../data/run{mode}/" + run_a_orig_path,
    run_b_rep_path=f"../data/run{mode}/" + run_b_rep_path,
    run_a_rep_path=f"../data/run{mode}/" + row["filename"],
    qrel_rpl_path="../data/qrels/" + qrel_rpl_path + mode,
    )

# %%
rpd_eval.trim()
rpd_eval.evaluate()

# %%
rpd_eval.trim(t=10)
rpd_eval.evaluate()

# %%
len(rpd_eval.rbo()["advanced"])
# Out:
# 124

# %%
df[df["dataset"]=="longeval"][["RMSE_ndcg_cut_5"]]
# Out:
#     RMSE_ndcg_cut_5
# 1               NaN
# 8               NaN
# 10              NaN
# 13              NaN
# 16              NaN
# 18              NaN
# 19              NaN
# 22              NaN
# 25              NaN
# 28              NaN
# 34              NaN
# 36              NaN
# 38              NaN
# 41              NaN
# 47              NaN

# %%
long[(long["dataset"]=="longeval") & (long["group"]=="RMSE")]
# Out:
#          method subcollection   dataset    variable  value group measure
# 110936  ColBERT            ST  longeval    RMSE_map  0.098  RMSE     map
# 110943      RRF            ST  longeval    RMSE_map  0.098  RMSE     map
# 110945  ColBERT            LT  longeval    RMSE_map  0.097  RMSE     map
# 110948   MonoT5            ST  longeval    RMSE_map  0.098  RMSE     map
# 110951     BM25            WT  longeval    RMSE_map    NaN  RMSE     map
# ...         ...           ...       ...         ...    ...   ...     ...
# 115754     BM25            ST  longeval  RMSE_set_F    NaN  RMSE   set_F
# 115756      RRF            WT  longeval  RMSE_set_F    NaN  RMSE   set_F
# 115758      RRF            LT  longeval  RMSE_set_F  0.002  RMSE   set_F
# 115761      d2q            WT  longeval  RMSE_set_F    NaN  RMSE   set_F
# 115767  ColBERT            WT  longeval  RMSE_set_F    NaN  RMSE   set_F
#
# [1320 rows x 7 columns]

# %%
measure="ndcg"
t = long[(long["subcollection"]=="ST") & (long["group"]=="RMSE") & (long["measure"].str.startswith(f"{measure}_cut")) & (long["method"]!="BM25")].pivot(index="measure", columns="method", values="value")
t["sort"] = t.index.str.extract(r"ndcg_cut_(\d+)").astype(int).values
t = t.sort_values("sort")
t["sort"] = t["sort"].astype(str)
t.set_index("sort", inplace=True)
t = t[["ColBERT", "MonoT5", "d2q", "RRF"]]
t
# Out:
# method  ColBERT  MonoT5    d2q    RRF
# sort
# 5         0.127   0.119  0.165  0.126
# 10        0.123   0.120  0.156  0.110
# 15        0.130   0.125  0.160  0.120
# 20        0.132   0.123  0.165  0.120
# 30        0.131   0.128  0.156  0.120
# 100       0.136   0.133  0.161  0.122
# 200       0.137   0.137  0.166  0.120
# 500       0.141   0.138  0.166  0.122
# 1000      0.141   0.138  0.166  0.127

# %%
def plot_rmse(long, subcollection, measure="ndcg"):
    # Data    
    t = long[(long["subcollection"]==subcollection) & (long["group"]=="RMSE") & (long["measure"].str.startswith(f"{measure}_cut")) & (long["method"]!="BM25")].pivot(index="measure", columns="method", values="value")
    t["sort"] = t.index.str.extract(r"ndcg_cut_(\d+)").astype(int).values
    t = t.sort_values("sort")
    t["sort"] = t["sort"].astype(str)
    t.set_index("sort", inplace=True)
    t = t[["ColBERT", "MonoT5", "d2q", "RRF"]]

    # plot
    plt.figure()
    # plt.rcParams.update({'font.size': 18})

    color_list = ['#ff7f00', '#33a02c', '#e31a1b', "#6a3c9a"]
    # color_list = ['#1f78b4', '#ff7f00', '#33a02c', '#e31a1b', "#6a3c9a", "#dbdbdb"]

    ax = t.plot.line(style='o-', figsize=(10, 6), color=color_list)
    ax.set_title(f"RMSE of nDCG at different cut-offs at {subcollection}")
    ax.set_xlabel('Cut-off values')
    ax.set_ylabel('RMSE')
    ax.legend(bbox_to_anchor=(0.5, -0.15), loc='upper center', ncol=4)

    # ax.set_xscale('log')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(True)  # disable grid
    plt.show()

    # ax.figure.savefig("../../MA/text/images/RMSE_WT-ST.png", dpi=300, bbox_inches='tight')

# %%
plot_rmse(long, "ST", measure="ndcg")

# %%
plot_rmse(long, "LT", measure="ndcg")

# %%
plot_rmse(long, "t2", measure="ndcg")

# %%
plot_rmse(long, "t3", measure="ndcg")

# %%
plot_rmse(long, "round2", measure="ndcg")

# %%
plot_rmse(long, "round3", measure="ndcg")
plot_rmse(long, "round4", measure="ndcg")
plot_rmse(long, "round5", measure="ndcg")

# %%
import matplotlib.pyplot as plt

# %%
subcollection = "ST"
t = long[(long["subcollection"]==subcollection) & (long["group"]=="RBO") & (long["method"]!="BM25")].pivot(index="measure", columns="method", values="value")
t["sort"] = t.index.str.extract(r"rbo_(\d+)").astype(int).values
t = t.sort_values("sort")
t["sort"] = t["sort"].astype(str)
t.set_index("sort", inplace=True)
t = t[["ColBERT", "MonoT5", "d2q", "RRF"]]
t
# Out:
# method  ColBERT  MonoT5    d2q    RRF
# sort
# 5         0.507   0.506  0.457  0.492
# 10        0.574   0.573  0.521  0.559
# 20        0.592   0.593  0.537  0.577
# 50        0.593   0.594  0.539  0.579
# 100       0.593   0.594  0.539  0.579
# 200       0.593   0.594  0.539  0.579

# %%
# def plot_rmse(long, subcollection, measure="ndcg"):
subcollection="round2" 

# Data    
t = long[(long["subcollection"]==subcollection) & (long["group"]=="RBO") & (long["method"]!="BM25")].pivot(index="measure", columns="method", values="value")
t["sort"] = t.index.str.extract(r"rbo_(\d+)").astype(int).values
t = t.sort_values("sort")
t["sort"] = t["sort"].astype(str)
t.set_index("sort", inplace=True)
t = t[["ColBERT", "MonoT5", "d2q", "RRF"]]

# plot
plt.figure()
# plt.rcParams.update({'font.size': 18})

color_list = ['#ff7f00', '#33a02c', '#e31a1b', "#6a3c9a"]
# color_list = ['#1f78b4', '#ff7f00', '#33a02c', '#e31a1b', "#6a3c9a", "#dbdbdb"]

ax = t.plot.line(style='o-', figsize=(10, 6), color=color_list)
ax.set_title(f"RBO at different cut-offs at {subcollection}")
ax.set_xlabel('Cut-off values')
ax.set_ylabel('RBO')
ax.legend(bbox_to_anchor=(0.5, -0.15), loc='upper center', ncol=4)

# ax.set_xscale('log')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(True)  # disable grid
plt.show()

# ax.figure.savefig("../../MA/text/images/RMSE_WT-ST.png", dpi=300, bbox_inches='tight')

# %%
import pandas as pd

# %%
a = pd.read_csv("../data/run-core_queries/run-longeval-ST-test-bm25_d2q10-pyterrier", sep=" ", names=["qid", "Q0", "docid", "rank", "score", "method"]).groupby("qid").head(5)[["qid", "docid", "rank"]]

# %%
b = pd.read_csv("../data/run-core_queries/run-longeval-WT-queries-bm25_d2q10-pyterrier", sep=" ", names=["qid", "Q0", "docid", "rank", "score", "method"]).groupby("qid").head(5)[["qid", "docid", "rank"]]

# %%
b.merge(a, on=["qid", "rank"]).head(30)
# Out:
#     qid          docid_x  rank          docid_y
# 0   147          1022249     0          1022249
# 1   147          1525214     1          1042962
# 2   147          1042962     2           681564
# 3   147           827190     3          1525214
# 4   147           681564     4          1051427
# 5   154           958678     0  doc072215804133
# 6   154           778793     1           778793
# 7   154           820862     2           232015
# 8   154           232015     3           958678
# 9   154           956777     4           820862
# 10  108           724233     0           724233
# 11  108           704115     1  doc072203710254
# 12  108           742848     2  doc072207803111
# 13  108           742274     3           704115
# 14  108           703979     4           742274
# 15  125           736691     0           736691
# 16  125           731010     1           731010
# 17  125           747964     2           747964
# 18  125           751900     3           818758
# 19  125           818758     4           751900
# 20   16           730640     0  doc072209602161
# 21   16  doc062200203193     1  doc072209601801
# 22   16  doc062200401969     2           730640
# 23   16           825444     3  doc072205109313
# 24   16          1553798     4  doc072205600291
# 25   40  doc062202100106     0  doc072215400240
# 26   40           729533     1           729533
# 27   40  doc062200202456     2            41035
# 28   40           748261     3           716966
# 29   40           720833     4           744107
